# %% [markdown]
# # HuggingFace SmolAgents

# %%
# !pip -q install smolagents
# !pip -q install litellm
# !pip install -qU duckduckgo-search
# !pip install requests markdownify
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Collecting markdownify
#   Downloading markdownify-1.1.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.9)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /usr/local/lib/python3.11/dist-packages (from markdownify) (4.13.4)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.11/dist-packages (from markdownify) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.9->markdownify) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.9->markdownify) (4.14.1)
# Downloading markdownify-1.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: markdownify
# Successfully installed markdownify-1.1.0

# %%
import os
import getpass

# %%
os.environ["HF_TOKEN"] = getpass.getpass("HF_TOKEN:")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3-2479724101.py in <cell line: 0>()
# ----> 1 os.environ["HF_TOKEN"] = getpass.getpass("HF_TOKEN:")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
os.environ['OPENAI_API_KEY'] = getpass.getpass("OPENAI_API_KEY:")
# Out:
# OPENAI_API_KEY:··········

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel
#agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)

model = LiteLLMModel(model_id="gpt-4.1-mini")
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)
# Out:
# /usr/local/lib/python3.11/dist-packages/smolagents/default_tools.py:135: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   self.ddgs = DDGS(**kwargs)
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()

# %%
agent.run("Dame el resultado final de sumar 35 veces pi")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Dame el resultado final de sumar 35 veces pi                                                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# ...
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# 109.95574287564276

# %%
print(agent.system_prompt)
# Out:
# You are an expert assistant who can solve any task using code blobs. You will be given a task to solve as best you can.
# To do so, you have been given access to a list of tools: these tools are basically Python functions which you can call with code.
# To solve the task, you must plan forward to proceed in a series of steps, in a cycle of Thought, Code, and Observation sequences.
#
# At each step, in the 'Thought:' sequence, you should first explain your reasoning towards solving the task and the tools that you want to use.
# Then in the Code sequence you should write the code in simple Python. The code sequence must be opened with '<code>', and closed with '</code>'.
# During each intermediate step, you can use 'print()' to save whatever important information you will then need.
# These print outputs will then appear in the 'Observation:' field, which will be available as input for the next step.
# In the end you have to return a final answer using the `final_answer` tool.
#
# Here are a few examples using notional tools:
# ---
# Task: "Generate an image of the oldest person in this document."
#
# Thought: I will proceed step by step and use the following tools: `document_qa` to find the oldest person in the document, then `image_generator` to generate an image according to the answer.
# <code>
# answer = document_qa(document=document, question="Who is the oldest person mentioned?")
# print(answer)
# </code>
# Observation: "The oldest person in the document is John Doe, a 55 year old lumberjack living in Newfoundland."
#
# Thought: I will now generate an image showcasing the oldest person.
# <code>
# image = image_generator("A portrait of John Doe, a 55-year-old man living in Canada.")
# final_answer(image)
# </code>
#
# ---
# Task: "What is the result of the following operation: 5 + 3 + 1294.678?"
#
# Thought: I will use python code to compute the result of the operation and then return the final answer using the `final_answer` tool
# <code>
# result = 5 + 3 + 1294.678
# final_answer(result)
# </code>
#
# ---
# Task:
# "Answer the question in the variable `question` about the image stored in the variable `image`. The question is in French.
# You have been provided with these additional arguments, that you can access using the keys as variables in your python code:
# {'question': 'Quel est l'animal sur l'image?', 'image': 'path/to/image.jpg'}"
#
# Thought: I will use the following tools: `translator` to translate the question into English and then `image_qa` to answer the question on the input image.
# <code>
# translated_question = translator(question=question, src_lang="French", tgt_lang="English")
# print(f"The translated question is {translated_question}.")
# answer = image_qa(image=image, question=translated_question)
# final_answer(f"The answer is {answer}")
# </code>
#
# ---
# Task:
# In a 1979 interview, Stanislaus Ulam discusses with Martin Sherwin about other great physicists of his time, including Oppenheimer.
# What does he say was the consequence of Einstein learning too much math on his creativity, in one word?
#
# Thought: I need to find and read the 1979 interview of Stanislaus Ulam with Martin Sherwin.
# <code>
# pages = web_search(query="1979 interview Stanislaus Ulam Martin Sherwin physicists Einstein")
# print(pages)
# </code>
# Observation:
# No result found for query "1979 interview Stanislaus Ulam Martin Sherwin physicists Einstein".
#
# Thought: The query was maybe too restrictive and did not find any results. Let's try again with a broader query.
# <code>
# pages = web_search(query="1979 interview Stanislaus Ulam")
# print(pages)
# </code>
# Observation:
# Found 6 pages:
# [Stanislaus Ulam 1979 interview](https://ahf.nuclearmuseum.org/voices/oral-histories/stanislaus-ulams-interview-1979/)
#
# [Ulam discusses Manhattan Project](https://ahf.nuclearmuseum.org/manhattan-project/ulam-manhattan-project/)
#
# (truncated)
#
# Thought: I will read the first 2 pages to know more.
# <code>
# for url in ["https://ahf.nuclearmuseum.org/voices/oral-histories/stanislaus-ulams-interview-1979/", "https://ahf.nuclearmuseum.org/manhattan-project/ulam-manhattan-project/"]:
#     whole_page = visit_webpage(url)
#     print(whole_page)
#     print("\n" + "="*80 + "\n")  # Print separator between pages
# </code>
# Observation:
# Manhattan Project Locations:
# Los Alamos, NM
# Stanislaus Ulam was a Polish-American mathematician. He worked on the Manhattan Project at Los Alamos and later helped design the hydrogen bomb. In this interview, he discusses his work at
# (truncated)
#
# Thought: I now have the final answer: from the webpages visited, Stanislaus Ulam says of Einstein: "He learned too much mathematics and sort of diminished, it seems to me personally, it seems to me his purely physics creativity." Let's answer in one word.
# <code>
# final_answer("diminished")
# </code>
#
# ---
# Task: "Which city has the highest population: Guangzhou or Shanghai?"
#
# Thought: I need to get the populations for both cities and compare them: I will use the tool `web_search` to get the population of both cities.
# <code>
# for city in ["Guangzhou", "Shanghai"]:
#     print(f"Population {city}:", web_search(f"{city} population")
# </code>
# Observation:
# Population Guangzhou: ['Guangzhou has a population of 15 million inhabitants as of 2021.']
# Population Shanghai: '26 million (2019)'
#
# Thought: Now I know that Shanghai has the highest population.
# <code>
# final_answer("Shanghai")
# </code>
#
# ---
# Task: "What is the current age of the pope, raised to the power 0.36?"
#
# Thought: I will use the tool `wikipedia_search` to get the age of the pope, and confirm that with a web search.
# <code>
# pope_age_wiki = wikipedia_search(query="current pope age")
# print("Pope age as per wikipedia:", pope_age_wiki)
# pope_age_search = web_search(query="current pope age")
# print("Pope age as per google search:", pope_age_search)
# </code>
# Observation:
# Pope age: "The pope Francis is currently 88 years old."
#
# Thought: I know that the pope is 88 years old. Let's compute the result using python code.
# <code>
# pope_current_age = 88 ** 0.36
# final_answer(pope_current_age)
# </code>
#
# Above example were using notional tools that might not exist for you. On top of performing computations in the Python code snippets that you create, you only have access to these tools, behaving like regular python functions:
# <code>
# def web_search(query: string) -> string:
#     """Performs a duckduckgo web search based on your query (think a Google search) then returns the top search results.
#
#     Args:
#         query: The search query to perform.
#     """
#
# def final_answer(answer: any) -> any:
#     """Provides a final answer to the given problem.
#
#     Args:
#         answer: The final answer to the problem
#     """
#
# </code>
#
# Here are the rules you should always follow to solve your task:
# 1. Always provide a 'Thought:' sequence, and a '<code>' sequence ending with '</code>', else you will fail.
# 2. Use only variables that you have defined!
# 3. Always use the right arguments for the tools. DO NOT pass the arguments as a dict as in 'answer = wikipedia_search({'query': "What is the place where James Bond lives?"})', but use the arguments directly as in 'answer = wikipedia_search(query="What is the place where James Bond lives?")'.
# 4. Take care to not chain too many sequential tool calls in the same code block, especially when the output format is unpredictable. For instance, a call to wikipedia_search has an unpredictable return format, so do not have another tool call that depends on its output in the same block: rather output results with print() to use them in the next block.
# 5. Call a tool only when needed, and never re-do a tool call that you previously did with the exact same parameters.
# 6. Don't name any new variable with the same name as a tool: for instance don't name a variable 'final_answer'.
# 7. Never create any notional variables in our code, as having these in your logs will derail you from the true variables.
# 8. You can use imports in your code, but only from the following list of modules: ['collections', 'datetime', 'itertools', 'math', 'queue', 'random', 're', 'stat', 'statistics', 'time', 'unicodedata']
# 9. The state persists between code executions: so if in one step you've created variables or imported modules, these will all persist.
# 10. Don't give up! You're in charge of solving the task, not providing directions to solve it.
#
# Now Begin!

# %%
agent.run("Puedo ir desde Andorra a Zaragoza en barco?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Puedo ir desde Andorra a Zaragoza en barco?                                                                     │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   info_andorra = web_search(query="Andorra geography and waterways")
#   print(info_andorra)
#   info_zaragoza = web_search(query="Zaragoza geography and waterways")
#   print(info_zaragoza)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Andorra - Wikitravel](https://wikitravel.org/en/Andorra)
# Jun 8, 2025 · Andorra is a small, mountainous country in the Pyrenees mountains between France and Spain. Cities
# [edit] Andorra la Vella - Capital of the Principality of Andorra Santa Coloma - …
#
# [Andorra La Vella - Wikitravel](https://wikitravel.org/en/Andorra_la_Vella)
# Apr 7, 2020 · Andorra la Vella is the capital of Andorra [1]. Get in Get around You should be able to walk around
# most of Andorra la Vella. The town is really in two parts. There is the newer section …
#
# [Andorra – Wikitravel](https://wikitravel.org/de/Andorra)
# Andorra war lange Zeit isoliert und verarmt, erlebte aber seit dem Zweiten Weltkrieg durch den Tourismus einen
# wirtschaftlichen Aufschwung. Viele Einwanderer (legal und illegal) werden heute …
#
# [Andorra – Wikitravel](https://wikitravel.org/hu/Andorra)
# EszközökMás nyelveken
#
# [Andorra - Wikitravel](https://wikitravel.org/nl/Andorra)
# Andorra heeft eigenlijk maar één echte stad, de hoofdstad Andorra-la-Vella. Ondanks de maar 23.000 inwoners is het
# er altijd erg druk. Dit komt doordat heel veel toeristen en dagjesmensen …
#
# [Europe - Wikitravel](https://wikitravel.org/en/Europe)
# Jul 5, 2025 · Andorra was due to release its own Euro coins in July 2013, but this has since been delayed. All
# other countries in Europe still retain their own currencies. Euros are widely accepted …
#
# [Catalonia - Wikitravel](https://wikitravel.org/en/Catalonia)
# Mar 27, 2025 · Catalonia [1] (Catalan: Catalunya, Occitan: Catalonha, Spanish: Cataluña) is a nationality and
# autonomous community in the northeast of Spain. It borders France and Andorra …
#
# [Andorre — Wikitravel](https://wikitravel.org/fr/Andorre)
# En Andorre, en hiver on ski, en été, on fait de la marche !
#
# [France - Wikitravel](https://wikitravel.org/en/France)
# Apr 29, 2025 · France, officially the French Republic (French: République Française), is a country with which
# almost every traveller has a relationship. Many dream of its joie de vivre shown by the …
#
# [Llista de codis telefònics per països -
# Wikitravel](https://wikitravel.org/ca/Llista_de_codis_telefònics_per_països)
# Llista de codis telefònics per països Quan truquem a un telèfon d'un altre país, normalment cal que marquem un
# prefixe per indicar que fem una trucada internacional (això varia en funció dels …
# ## Search Results
#
# [Zaragoza - Wikipedia](https://en.m.wikipedia.org/wiki/Zaragoza)
# Zaragoza (Spanish: [θaɾaˈɣoθa] ⓘ), traditionally known in English as Saragossa[6] (/ ˌsærəˈɡɒsə / SARR-ə-GOSS-ə),
# [7] is the capital city of the province of Zaragoza and of the autonomous …
#
# [18 Things to Do in Zaragoza, Spain - The Spain Travel
# Guru](https://thespaintravelguru.com/things-to-do-in-zaragoza-spain/)
# Jan 10, 2025 · Enjoy these incredible things to do in Zaragoza including museums, historical sites, churches, food,
# and more!
#
# [Tourism in Zaragoza. What to see | spain.info](https://www.spain.info/en/destination/zaragoza/)
# With more than 2000 years of history, Zaragoza is known for its colossal Basilica del Pilar, its Roman foundation,
# its cultural diversity and the approachability of its people. But its visitors have …
#
# [Zaragoza | Spain, Map, Population, & Facts | Britannica](https://www.britannica.com/place/Zaragoza-Spain)
# Zaragoza, city, capital of Zaragoza provincia (province), in central Aragon comunidad autónoma (autonomous
# community), northeastern Spain. It lies on the south bank of the Ebro River (there …
#
# [Zaragoza, Spain: All You Must Know Before You Go (2025) -
# Tripadvisor](https://www.tripadvisor.com/Tourism-g187448-Zaragoza_Province_of_Zaragoza_Aragon-Vacations.html)
# A rich blend of the historic and modern, Zaragoza sits on the banks of the Ebro River. Stroll in the center of town
# near San Miguel's pedestrian ways or around the Plaza de los Sitios, where you …
#
# [The Ultimate Zaragoza Travel Guide! Everything You Need To
# Know!](https://thewanderingquinn.com/zaragoza-spain-city-guide/)
# Sep 20, 2018 · Zaragoza is in the Northern part of Spain in the Aragon region and it’s the 5th biggest city in
# Spain. Why visit Zaragoza? It’s a lesser-known Spanish City which means it’s not …
#
# [9 must-see places in Zaragoza to discover at least once in your
# life](https://www.fascinatingspain.com/articulo/what-to-see-in-aragon/must-see-places-in-zaragoza-spain/20241112161
# 559067644.html)
# 4 days ago · Zaragoza is a boisterous yet welcoming city with plenty to boast about and every part of Aragon ’s
# capital holds a surprise. The city’s more than two-thousand-year history is captured …
#
# [Zaragoza City Guide](https://www.whatzaragoza.com/)
# The capital of the Province of Aragon, Zaragoza is a stunning city shaped around the banks of one of the most
# important and picturesque rivers in Spain: the Ebro.
#
# [Why Visit Zaragoza: Spain’s Most Overlooked City](https://www.wandersmiles.com/reasons-to-visit-zaragoza-spain/)
# 1 day ago · Visit Zaragoza: Roman and Moorish history and local cuisine. Spain’s fifth-largest city is the gateway
# to Aragon's wine route, castles and adventure activities.
#
# [Zaragoza – Travel guide at Wikivoyage](https://en.m.wikivoyage.org/wiki/Zaragoza)
# Zaragoza is the capital and largest city of Aragon in Spain, and one of Spain's five largest cities, but it is one
# of the least known outside of Spain. Founded on the river Ebro during the Roman Empire …
#
# Out: None
# [Step 1: Duration 4.37 seconds| Input tokens: 1,944 | Output tokens: 96]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   boat_possibility = web_search(query="Can you travel by boat from Andorra to Zaragoza?")
#   print(boat_possibility)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Canva: Visual Suite for Everyone](https://www.canva.com/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# What will you design today? With Canva you can design, generate, print, and work on anything.
#
# [Canva Free | Design anything, together and for
# free](https://www.canva.com/free/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Try Design School courses Watch tutorials on how you can design anything and achieve your goals with Canva.
#
# [Canva: una Suite Visual para todo el mundo](https://www.canva.com/es_es/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Canva es una herramienta online de diseño gráfico de uso gratuito. Utilízala para crear publicaciones para redes
# sociales, presentaciones, carteles, vídeos, logos y mucho más.
#
# [Canva Miễn phí](https://www.canva.com/vi_vn/free/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Thiết kế dễ dàng và miễn phí với Canva. Tạo nội dung trực quan tuyệt vời mà không cần kinh nghiệm thiết kế. Tự bắt
# đầu hoặc mời người khác cộng tác.
#
# [Create beautiful graphics with Canva](https://www.canva.com/create/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Design anything with ease in Canva Create anything in a snap, from presentations and logos to social media posts.
# Get inspired and see what you can do on Canva, no design skills or …
#
# [Suite Visual de Canva para todo el mundo](https://www.canva.com/es_mx/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Canva es una herramienta de diseño gráfico en línea gratuita. Puedes usarla para crear publicaciones para redes
# sociales, presentaciones, posters, videos, logos y mucho más.
#
# [Canva Pro | Your all-in-one design solution](https://www.canva.com/pro/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# With Canva Free, you can create, design, and explore a library of free templates and content to bring your ideas to
# life. For access to premium features like Magic Resize, Brand Kit, and …
#
# [Canva: Visual Suite สำหรับทุกคน](https://www.canva.com/th_th/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Canva คือเครื่องมือออกแบบกราฟิกออนไลน์ที่ใช้งานได้ฟรี ซึ่ง ...
#
# [Canva: um Kit de Criação Visual para todo
# mundo](https://www.canva.com/pt_br/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# O Canva é uma ferramenta gratuita de design gráfico online que você pode usar para criar posts para redes sociais,
# apresentações, cartazes, vídeos, logotipos e muito mais.
#
# [Log in to your Canva account to start creating beautiful
# designs](https://www.canva.com/class/join/?msockid=1889c7d2762d6e2f174fd1fb778f6f1d)
# Create beautiful designs with your team. Login with your email address, mobile number, Google, Facebook or Apple.
#
# Out: None
# [Step 2: Duration 3.43 seconds| Input tokens: 5,484 | Output tokens: 242]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("No, no se puede ir de Andorra a Zaragoza en barco porque Andorra es un país montañoso sin salida
#   navegable a ríos o al mar y Zaragoza está situada en un río sin conexión directa por agua con Andorra.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: No, no se puede ir de Andorra a Zaragoza en barco porque Andorra es un país montañoso sin salida
# navegable a ríos o al mar y Zaragoza está situada en un río sin conexión directa por agua con Andorra.
# [Step 3: Duration 4.94 seconds| Input tokens: 10,030 | Output tokens: 383]
# 'No, no se puede ir de Andorra a Zaragoza en barco porque Andorra es un país montañoso sin salida navegable a ríos o al mar y Zaragoza está situada en un río sin conexión directa por agua con Andorra.'

# %%
agent.run("Va a subir bitcoin en los proximos dias?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Va a subir bitcoin en los proximos dias?                                                                        │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bitcoin_trend = web_search(query="Bitcoin price prediction next few days")
#   print(bitcoin_trend)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Bitcoin - Open source P2P money](https://bitco.in/)
# Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be used to pay for
# goods and services, just like paper money.
#
# [Download - Bitcoin](https://bitco.in/en/download)
# Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be used to pay for
# goods and services, just like paper money.
#
# [Bitcoin Forum](https://bitco.in/forum/)
# Bitcoin Forum is a community of developers, academics, and entrepreneurs dedicated to promoting and improving
# Bitcoin.
#
# [Bitcoin-Qt version 0.8.6 released](https://bitco.in/en/release/v0-8-6)
# Dec 9, 2013 · Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be
# used to pay for goods and services, just like paper money.
#
# [Choose your wallet - Bitcoin](https://bitco.in/en/choose-your-wallet)
# Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be used to pay for
# goods and services, just like paper money.
#
# [Descargar - Bitcoin](https://bitco.in/es/descargar)
# Debe tener paciencia La sincronizazción inicial de Bitcoin Core puede tomar un largo tiempo. Debería asegurarse de
# que dispone de suficiente ancho de banda y espacio de almacenamiento …
#
# [다운로드 - Bitcoin](https://bitco.in/ko/download)
# Bitcoin Core 다운로드 최신 버전: 0.10.2 Windows 64 bit - 32 bit Windows (zip) 64 bit - 32 bit Mac OS X dmg - tar.gz
#
# [Download - Bitcoin](https://bitco.in/pt_BR/download)
# Você precisará ter paciência A sincronização inicial com Bitcoin Core pode levar bastante tempo. Você deve
# assegurar-se de ter largura de banda e memória suficiente para o tamanho inteiro do …
#
# [下载 - 比特币](https://bitco.in/zh_CN/download)
# Bitcoin Core 是一个社区驱动的免费开源项目，用户可以下载并运行它以支持比特币网络。
#
# [Téléchargement - Bitcoin](https://bitco.in/fr/telecharger)
# Vérifiez votre bande-passante et votre espace La synchronisation initiale de Bitcoin Core peut prendre du temps et
# télécharger beaucoup de données. Assurez-vous de disposer de …
#
# Out: None
# [Step 1: Duration 1.74 seconds| Input tokens: 1,943 | Output tokens: 96]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bitcoin_price_news = web_search(query="Bitcoin short term price prediction recent news")
#   print(bitcoin_price_news)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Bitcoin - Open source P2P money](https://bitco.in/)
# Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be used to pay for
# goods and services, just like paper money.
#
# [Download - Bitcoin](https://bitco.in/en/download)
# Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be used to pay for
# goods and services, just like paper money.
#
# [Bitcoin Forum](https://bitco.in/forum/)
# Bitcoin Forum is a community of developers, academics, and entrepreneurs dedicated to promoting and improving
# Bitcoin.
#
# [Bitcoin-Qt version 0.8.6 released](https://bitco.in/en/release/v0-8-6)
# Dec 9, 2013 · Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be
# used to pay for goods and services, just like paper money.
#
# [Choose your wallet - Bitcoin](https://bitco.in/en/choose-your-wallet)
# Bitcoin is a peer-to-peer electronic payment system. It is the leading online currency and can be used to pay for
# goods and services, just like paper money.
#
# [Descargar - Bitcoin](https://bitco.in/es/descargar)
# Debe tener paciencia La sincronizazción inicial de Bitcoin Core puede tomar un largo tiempo. Debería asegurarse de
# que dispone de suficiente ancho de banda y espacio de almacenamiento …
#
# [다운로드 - Bitcoin](https://bitco.in/ko/download)
# Bitcoin Core 다운로드 최신 버전: 0.10.2 Windows 64 bit - 32 bit Windows (zip) 64 bit - 32 bit Mac OS X dmg - tar.gz
#
# [Download - Bitcoin](https://bitco.in/pt_BR/download)
# Você precisará ter paciência A sincronização inicial com Bitcoin Core pode levar bastante tempo. Você deve
# assegurar-se de ter largura de banda e memória suficiente para o tamanho inteiro do …
#
# [下载 - 比特币](https://bitco.in/zh_CN/download)
# Bitcoin Core 是一个社区驱动的免费开源项目，用户可以下载并运行它以支持比特币网络。
#
# [Téléchargement - Bitcoin](https://bitco.in/fr/telecharger)
# Vérifiez votre bande-passante et votre espace La synchronisation initiale de Bitcoin Core peut prendre du temps et
# télécharger beaucoup de données. Assurez-vous de disposer de …
#
# Out: None
# [Step 2: Duration 2.97 seconds| Input tokens: 4,558 | Output tokens: 213]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("No se puede predecir con certeza si Bitcoin subirá en los próximos días, ya que su precio es
#   altamente volátil y las búsquedas no arrojaron información reciente o confiable sobre su movimiento futuro.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: No se puede predecir con certeza si Bitcoin subirá en los próximos días, ya que su precio es
# altamente volátil y las búsquedas no arrojaron información reciente o confiable sobre su movimiento futuro.
# [Step 3: Duration 2.89 seconds| Input tokens: 7,867 | Output tokens: 404]
# 'No se puede predecir con certeza si Bitcoin subirá en los próximos días, ya que su precio es altamente volátil y las búsquedas no arrojaron información reciente o confiable sobre su movimiento futuro.'

# %%
agent.run("Si quiero invertir en un ETF seguro a largo plazo, cual es el mejor?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Si quiero invertir en un ETF seguro a largo plazo, cual es el mejor?                                            │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_query = "best safe long term ETF investment 2024"
#   results = web_search(query=search_query)
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Execution logs:
# ## Search Results
#
# ["What was best" vs "what was the best"? - English Language
# …](https://ell.stackexchange.com/questions/182964/what-was-best-vs-what-was-the-best)
# Oct 18, 2018 · In your context, the best relates to {something}, whereas best relates to a course of action.
# Plastic, wood, or metal container? What was the best choice for this purpose? Plastic, …
#
# [adverbs - About "best" , "the best" , and "most" - English Language
# ...](https://ell.stackexchange.com/questions/106993/about-best-the-best-and-most)
# Oct 20, 2016 · Both sentences could mean the same thing, however I like you best. I like chocolate best, better
# than anything else can be used when what one is choosing from is not specified I like …
#
# ["Which one is the best" vs. "which one the best
# is"](https://ell.stackexchange.com/questions/315927/which-one-is-the-best-vs-which-one-the-best-is)
# May 25, 2022 · "Which one is the best" is obviously a question format, so it makes sense that " which one the best
# is " should be the correct form. This is very good instinct, and you could even …
#
# [how to use “best” as adverb? - English Language Learners Stack
# …](https://ell.stackexchange.com/questions/203492/how-to-use-best-as-adverb)
# Apr 2, 2019 · Your example already shows how to use "best" as an adverb. It is also a superlative, like "greatest",
# or "highest", so just as you would use it as an adjective to show that something is …
#
# [articles - "it is best" vs. "it is the best" - English Language
# ...](https://ell.stackexchange.com/questions/77629/it-is-best-vs-it-is-the-best)
# Jan 2, 2016 · The word "best" is an adjective, and adjectives do not take articles by themselves. Because the noun
# car is modified by the superlative adjective best, and because this makes the …
#
# [grammar - It was the best ever vs it is the best ever? - English
# ...](https://ell.stackexchange.com/questions/336995/it-was-the-best-ever-vs-it-is-the-best-ever)
# May 29, 2023 · So, " It is the best ever " means it's the best of all time, up to the present. " It was the best
# ever " means either it was the best up to that point in time, and a better one may have …
#
# [Way of / to / for - English Language Learners Stack
# Exchange](https://ell.stackexchange.com/questions/53441/word-choice-way-of-to-for)
# Mar 25, 2015 · The best way to use "the best way" is to follow it with an infinitive. However, this is not the only
# way to use the phrase; "the best way" can also be followed by of with a gerund: The …
#
# [Is the clause "I ever have" in the sentence "the best gift I ever have
# ...](https://ell.stackexchange.com/questions/264504/is-the-clause-i-ever-have-in-the-sentence-the-best-gift-i-ever-
# have-grammati)
# Oct 26, 2020 · "the best gift that I ever have" is not a "sentence" - it's a noun phrase. Valid phrasings for which
# are the best gift I [have] ever had - with or without that auxiliary had, which …
#
# [expressions - "it's best" - how should it be used? - English
# …](https://ell.stackexchange.com/questions/267973/its-best-how-should-it-be-used)
# Dec 8, 2020 · It's best that he bought it yesterday. or It's good that he bought it yesterday. 2a has a quite
# different meaning, implying that what is being approved of is not that the purchase be …
#
# [Would be or will be - English Language Learners Stack
# Exchange](https://ell.stackexchange.com/questions/226381/would-be-or-will-be)
# Oct 1, 2019 · It indicates items that (with the best understanding) are going to happen. Would is a conditional
# verb form. It states that something happens based on something else. Sometimes the …
#
# Out: None
# [Step 1: Duration 2.33 seconds| Input tokens: 1,949 | Output tokens: 89]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_query_2 = "most recommended safe ETFs for long-term investment 2024"
#   results_2 = web_search(query=search_query_2)
#   print(results_2)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [grammar - When to use "most" or "the most" - English
# Language](https://english.stackexchange.com/questions/257401/when-to-use-most-or-the-most)
# Jul 7, 2015 · The adverbial use of the definite noun the most synonymous with the bare-adverbial most to modify an
# entire clause or predicate has been in use since at least the 1500s and is an …
#
# [superlative degree - How/when does one use "a most"? - English
# …](https://english.stackexchange.com/questions/85112/how-when-does-one-use-a-most)
# I've recently come across a novel called A most wanted man, after which being curious I found a TV episode called A
# most unusual camera. Could someone shed some light on how to use "a most" …
#
# ['A most' -- is it odd usage? - English Language & Usage Stack
# …](https://english.stackexchange.com/questions/386060/a-most-is-it-odd-usage)
# Apr 24, 2017 · Grammar books routinely insist on "the most" as for all superlatives, but I can recall certain cases
# where 'most' has not been used as 'the superlative' but only as 'a superlative!' (as …
#
# [Subject-verb agreement: "Most of the x of y"
# is/are?](https://english.stackexchange.com/questions/354382/subject-verb-agreement-most-of-the-x-of-y-is-are)
# Oct 20, 2016 · In your 1st example, the head of the subject NP is the fused determiner-head 'most', not plural
# 'paperbacks'. ‘Most’ can occur with both singular and plural partitives, but here ‘that …
#
# ["Most of which" or "most of whom" or "most of
# who"?](https://english.stackexchange.com/questions/16507/most-of-which-or-most-of-whom-or-most-of-who)
# Apr 1, 2022 · Since "most of _____" is a prepositional phrase, the correct usage would be "most of whom." The
# phrase "most of who" should probably never be used. Another way to think about …
#
# [verb agreement - "Most of what" and "is" or "are" - English
# …](https://english.stackexchange.com/questions/195862/most-of-what-and-is-or-are)
# Jul 30, 2017 · In your example, books ARE what you have read most, so I would agree that in diagrammatic reasoning
# most of what you've read ARE books. Of all of the various materials I've …
#
# [What does the word "most" mean? - English Language & Usage
# …](https://english.stackexchange.com/questions/355083/what-does-the-word-most-mean)
# Oct 24, 2016 · Most is defined by the attributes you apply to it. "Most of your time" would imply more than half,
# "the most time" implies more than the rest in your stated set. Your time implies …
#
# [meaning - Is "most" equivalent to "a majority of"? - English
# …](https://english.stackexchange.com/questions/55920/is-most-equivalent-to-a-majority-of)
# Here "most" means "a plurality". Most dentists recommend Colgate toothpaste. Here it is ambiguous about whether
# there is a bare majority or a comfortable majority. From the 2nd …
#
# [Most is vs most are - English Language & Usage Stack
# Exchange](https://english.stackexchange.com/questions/93304/most-is-vs-most-are)
# Most is what is called a determiner. A determiner is "a word, such as a number, article, personal pronoun, that
# determines (limits) the meaning of a noun phrase." Some determiners can only be …
#
# ["most" vs "the most", specifically as an adverb at the end of
# sentence](https://english.stackexchange.com/questions/238372/most-vs-the-most-specifically-as-an-adverb-at-the-end-
# of-sentence)
# Apr 9, 2015 · Which one of the following sentences is the most canonical? I know most vs. the most has been
# explained a lot, but my doubts pertain specifically to which one to use at the end of a …
#
# Out: None
# [Step 2: Duration 2.95 seconds| Input tokens: 4,983 | Output tokens: 206]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_query_3 = "best safe ETF for long-term investment 2024 finance expert recommendations"
#   results_3 = web_search(query=search_query_3)
#   print(results_3)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# ["What was best" vs "what was the best"? - English Language
# …](https://ell.stackexchange.com/questions/182964/what-was-best-vs-what-was-the-best)
# Oct 18, 2018 · In your context, the best relates to {something}, whereas best relates to a course of action.
# Plastic, wood, or metal container? What was the best choice for this purpose? Plastic, …
#
# [adverbs - About "best" , "the best" , and "most" - English Language
# ...](https://ell.stackexchange.com/questions/106993/about-best-the-best-and-most)
# Oct 20, 2016 · Both sentences could mean the same thing, however I like you best. I like chocolate best, better
# than anything else can be used when what one is choosing from is not specified I like …
#
# ["Which one is the best" vs. "which one the best
# is"](https://ell.stackexchange.com/questions/315927/which-one-is-the-best-vs-which-one-the-best-is)
# May 25, 2022 · "Which one is the best" is obviously a question format, so it makes sense that " which one the best
# is " should be the correct form. This is very good instinct, and you could even …
#
# [how to use “best” as adverb? - English Language Learners Stack
# …](https://ell.stackexchange.com/questions/203492/how-to-use-best-as-adverb)
# Apr 2, 2019 · Your example already shows how to use "best" as an adverb. It is also a superlative, like "greatest",
# or "highest", so just as you would use it as an adjective to show that something is …
#
# [articles - "it is best" vs. "it is the best" - English Language
# ...](https://ell.stackexchange.com/questions/77629/it-is-best-vs-it-is-the-best)
# Jan 2, 2016 · The word "best" is an adjective, and adjectives do not take articles by themselves. Because the noun
# car is modified by the superlative adjective best, and because this makes the …
#
# [grammar - It was the best ever vs it is the best ever? - English
# ...](https://ell.stackexchange.com/questions/336995/it-was-the-best-ever-vs-it-is-the-best-ever)
# May 29, 2023 · So, " It is the best ever " means it's the best of all time, up to the present. " It was the best
# ever " means either it was the best up to that point in time, and a better one may have …
#
# [Way of / to / for - English Language Learners Stack
# Exchange](https://ell.stackexchange.com/questions/53441/word-choice-way-of-to-for)
# Mar 25, 2015 · The best way to use "the best way" is to follow it with an infinitive. However, this is not the only
# way to use the phrase; "the best way" can also be followed by of with a gerund: The …
#
# [Is the clause "I ever have" in the sentence "the best gift I ever have
# ...](https://ell.stackexchange.com/questions/264504/is-the-clause-i-ever-have-in-the-sentence-the-best-gift-i-ever-
# have-grammati)
# Oct 26, 2020 · "the best gift that I ever have" is not a "sentence" - it's a noun phrase. Valid phrasings for which
# are the best gift I [have] ever had - with or without that auxiliary had, which …
#
# [expressions - "it's best" - how should it be used? - English
# …](https://ell.stackexchange.com/questions/267973/its-best-how-should-it-be-used)
# Dec 8, 2020 · It's best that he bought it yesterday. or It's good that he bought it yesterday. 2a has a quite
# different meaning, implying that what is being approved of is not that the purchase be …
#
# [Would be or will be - English Language Learners Stack
# Exchange](https://ell.stackexchange.com/questions/226381/would-be-or-will-be)
# Oct 1, 2019 · It indicates items that (with the best understanding) are going to happen. Would is a conditional
# verb form. It states that something happens based on something else. Sometimes the …
#
# Out: None
# [Step 3: Duration 3.07 seconds| Input tokens: 9,113 | Output tokens: 317]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Common examples of safe ETFs for long-term investment often include:
#   # - Vanguard Total Stock Market ETF (VTI)
#   # - iShares Core S&P 500 ETF (IVV)
#   # - Vanguard FTSE Developed Markets ETF (VEA)
#   # - Vanguard Total Bond Market ETF (BND)
#   # - Schwab U.S. Aggregate Bond ETF (SCHZ)
#   #
#   # These ETFs are well diversified and considered suitable for long-term investors looking for stable growth
#   with risk management.
#   safe_etf_examples = [
#       "Vanguard Total Stock Market ETF (VTI)",
#       "iShares Core S&P 500 ETF (IVV)",
#       "Vanguard FTSE Developed Markets ETF (VEA)",
#       "Vanguard Total Bond Market ETF (BND)",
#       "Schwab U.S. Aggregate Bond ETF (SCHZ)"
#   ]
#
#   answer_text = (
#       "Para una inversión segura a largo plazo, los ETFs diversificados y con historial "
#       "de estabilidad suelen ser los más recomendados. Algunos ejemplos conocidos son: "
#       + ", ".join(safe_etf_examples) +
#       ". Es importante consultar con un asesor financiero para adaptar la inversión a su perfil."
#   )
#
#   final_answer(answer_text)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Para una inversión segura a largo plazo, los ETFs diversificados y con historial de estabilidad
# suelen ser los más recomendados. Algunos ejemplos conocidos son: Vanguard Total Stock Market ETF (VTI), iShares
# Core S&P 500 ETF (IVV), Vanguard FTSE Developed Markets ETF (VEA), Vanguard Total Bond Market ETF (BND), Schwab
# U.S. Aggregate Bond ETF (SCHZ). Es importante consultar con un asesor financiero para adaptar la inversión a su
# perfil.
# [Step 4: Duration 4.77 seconds| Input tokens: 14,362 | Output tokens: 660]
# 'Para una inversión segura a largo plazo, los ETFs diversificados y con historial de estabilidad suelen ser los más recomendados. Algunos ejemplos conocidos son: Vanguard Total Stock Market ETF (VTI), iShares Core S&P 500 ETF (IVV), Vanguard FTSE Developed Markets ETF (VEA), Vanguard Total Bond Market ETF (BND), Schwab U.S. Aggregate Bond ETF (SCHZ). Es importante consultar con un asesor financiero para adaptar la inversión a su perfil.'

# %%
from smolagents import CodeAgent, VisitWebpageTool
agent = CodeAgent(
    tools = [VisitWebpageTool()],
    model=model,
    additional_authorized_imports=["requests", "markdownify"],
)

agent.run("Si quiero invertir en un ETF seguro a largo plazo, cual es el mejor?")
# Out:
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Si quiero invertir en un ETF seguro a largo plazo, cual es el mejor?                                            │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url = "https://www.investopedia.com/best-etfs-for-long-term-investing-5180779"
#   page_content = visit_webpage(url)
#   print(page_content[:1000])  # Only printing the first 1000 characters to check the content
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# Execution logs:
# Error fetching the webpage: 404 Client Error: Not Found for url:
# https://www.investopedia.com/best-etfs-for-long-term-investing-5180779
#
# Out: None
# [Step 1: Duration 3.44 seconds| Input tokens: 1,956 | Output tokens: 179]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url2 = "https://www.fool.com/investing/stock-market/market-sectors/etfs/best-etfs-to-buy/"
#   page2_content = visit_webpage(url2)
#   print(page2_content[:1000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 404 Client Error: Not Found for url:
# https://www.fool.com/investing/stock-market/market-sectors/etfs/best-etfs-to-buy/
#
# Out: None
# [Step 2: Duration 2.66 seconds| Input tokens: 4,237 | Output tokens: 311]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Visiting a search results page for the query (simulate web_search by visiting a search page)
#   search_url = "https://www.google.com/search?q=best+safe+long+term+etfs+2024"
#   search_page_content = visit_webpage(search_url)
#   print(search_page_content[:1000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Google Search
#
# Please click [here](/httpservice/retry/enablejs?sei=WG91aPyvPO_ep84PuZTf4QM) if you are not redirected within a few
# seconds.
#
# If you're having trouble accessing Google Search, please [click
# here](/search?q=best+safe+long+term+etfs+2024&sca_esv=b9187f4daeb51a28&ie=UTF-8&emsg=SG_REL&sei=WG91aPyvPO_ep84PuZT
# f4QM), or send [feedback](https://support.google.com/websearch).
#
# Out: None
# [Step 3: Duration 2.51 seconds| Input tokens: 6,795 | Output tokens: 460]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url_wiki_etf = "https://en.wikipedia.org/wiki/Exchange-traded_fund"
#   wiki_etf_page = visit_webpage(url_wiki_etf)
#   print(wiki_etf_page[:1000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# Execution logs:
# Exchange-traded fund - Wikipedia
#
# [Jump to content](#bodyContent)
#
# Main menu
#
# Main menu
#
# move to sidebar
# hide
#
# Navigation
#
# * [Main page](/wiki/Main_Page "Visit the main page [z]")
# * [Contents](/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")
# * [Current events](/wiki/Portal:Current_events "Articles related to current events")
# * [Random article](/wiki/Special:Random "Visit a randomly selected article [x]")
# * [About Wikipedia](/wiki/Wikipedia:About "Learn about Wikipedia and how it works")
# * [Contact us](//en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")
#
# Contribute
#
# * [Help](/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")
# * [Learn to edit](/wiki/Help:Introduction "Learn how to edit Wikipedia")
# * [Community portal](/wiki/Wikipedia:Community_portal "The hub for editors")
# * [Recent changes](/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")
# * [Upload file](/wiki/Wikipedia:File_upload_wizard "Add images or other media for u
#
# Out: None
# [Step 4: Duration 3.52 seconds| Input tokens: 9,752 | Output tokens: 622]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content="Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content="Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print(wiki_etf_page[:3000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Exchange-traded fund - Wikipedia
#
# [Jump to content](#bodyContent)
#
# Main menu
#
# Main menu
#
# move to sidebar
# hide
#
# Navigation
#
# * [Main page](/wiki/Main_Page "Visit the main page [z]")
# * [Contents](/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")
# * [Current events](/wiki/Portal:Current_events "Articles related to current events")
# * [Random article](/wiki/Special:Random "Visit a randomly selected article [x]")
# * [About Wikipedia](/wiki/Wikipedia:About "Learn about Wikipedia and how it works")
# * [Contact us](//en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")
#
# Contribute
#
# * [Help](/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")
# * [Learn to edit](/wiki/Help:Introduction "Learn how to edit Wikipedia")
# * [Community portal](/wiki/Wikipedia:Community_portal "The hub for editors")
# * [Recent changes](/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")
# * [Upload file](/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")
# * [Special pages](/wiki/Special:SpecialPages)
#
# [![](/static/images/icons/wikipedia.png)
#
# ![Wikipedia](/static/images/mobile/copyright/wikipedia-wordmark-en.svg)
# ![The Free Encyclopedia](/static/images/mobile/copyright/wikipedia-tagline-en.svg)](/wiki/Main_Page)
#
# [Search](/wiki/Special:Search "Search Wikipedia [f]")
#
# Search
#
# Appearance
#
# *
# [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=e
# n)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Exchange-traded+fund "You are encouraged to
# create an account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Exchange-traded+fund "You're encouraged to log in;
# however, it's not mandatory. [o]")
#
# Personal tools
#
# *
# [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=e
# n)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Exchange-traded+fund "You are encouraged to
# create an account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Exchange-traded+fund "You're encouraged to log in;
# however, it's not mandatory. [o]")
#
# Pages for logged out editors [learn more](/wiki/Help:Introduction)
#
# * [Contributions](/wiki/Special:MyContributions "A list of edits made from this IP address [y]")
# * [Talk](/wiki/Special:MyTalk "Discussion about edits from this IP address [n]")
#
# Contents
# --------
#
# move to sidebar
# hide
#
# * [(Top)](#)
# * [1
#   ETFs vs. mutual funds](#ETFs_vs._mutual_funds)
#
#   Toggle ETFs vs. mutual funds subsection
#   + [1.1
#     Costs and fees](#Costs_and_fees)
#   + [1.2
#     Taxation](#Taxation)
#   + [1.3
#     Trading](#Trading)
#   + [1.4
#     Transparency](#Transparency)
# * [2
#   Categories of ETFs](#Categories_of_ETFs)
#
#   Toggle Categories of ETFs subsection
#   + [2.1
#     Index ETFs](#Index_ETFs)
#   + [2.2
#     Actively managed ETFs](#Actively_managed_ETFs)
#   + [2.3
#     T
#
# Out: None
# [Step 5: Duration 1.58 seconds| Input tokens: 13,224 | Output tokens: 728]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url_etf_com = "https://www.etf.com/etf-finder"
#   etf_com_page = visit_webpage(url_etf_com)
#   print(etf_com_page[:1000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 403 Client Error: Forbidden for url: https://www.etf.com/etf-finder
#
# Out: None
# [Step 6: Duration 3.17 seconds| Input tokens: 17,689 | Output tokens: 939]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url_morningstar = "https://www.morningstar.com/articles/1084669/best-etfs-for-long-term-investing"
#   morningstar_page = visit_webpage(url_morningstar)
#   print(morningstar_page[:1000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Execution logs:
# Error fetching the webpage: 403 Client Error: Forbidden for url:
# https://www.morningstar.com/articles/1084669/best-etfs-for-long-term-investing
#
# Out: None
# [Step 7: Duration 3.18 seconds| Input tokens: 22,487 | Output tokens: 1,113]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 8 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   answer = ("Para una inversión segura a largo plazo en un ETF, se recomienda generalmente un ETF que "
#             "sigue un índice amplio y diversificado como el S&P 500. Un ejemplo muy popular y considerado "
#             "seguro es el ETF Vanguard S&P 500 (VOO). Este ETF ofrece diversificación en empresas grandes "
#             "estadounidenses y ha mostrado buen rendimiento histórico a largo plazo. También pueden considerarse
#   "
#             "ETFs de mercado total (como VTI) o ETFs de bonos para menor riesgo. La elección depende de tu perfil
#   "
#             "de riesgo, pero VOO es un referente como ETF seguro para largo plazo.")
#   final_answer(answer)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Para una inversión segura a largo plazo en un ETF, se recomienda generalmente un ETF que sigue un
# índice amplio y diversificado como el S&P 500. Un ejemplo muy popular y considerado seguro es el ETF Vanguard S&P
# 500 (VOO). Este ETF ofrece diversificación en empresas grandes estadounidenses y ha mostrado buen rendimiento
# histórico a largo plazo. También pueden considerarse ETFs de mercado total (como VTI) o ETFs de bonos para menor
# riesgo. La elección depende de tu perfil de riesgo, pero VOO es un referente como ETF seguro para largo plazo.
# [Step 8: Duration 4.77 seconds| Input tokens: 27,601 | Output tokens: 1,405]
# 'Para una inversión segura a largo plazo en un ETF, se recomienda generalmente un ETF que sigue un índice amplio y diversificado como el S&P 500. Un ejemplo muy popular y considerado seguro es el ETF Vanguard S&P 500 (VOO). Este ETF ofrece diversificación en empresas grandes estadounidenses y ha mostrado buen rendimiento histórico a largo plazo. También pueden considerarse ETFs de mercado total (como VTI) o ETFs de bonos para menor riesgo. La elección depende de tu perfil de riesgo, pero VOO es un referente como ETF seguro para largo plazo.'

# %%
agent.run("Que año deberia haber comprado 1000€ de bitcoin para hoy tener un millon de € (hoy es 14/07/2025)")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Que año deberia haber comprado 1000€ de bitcoin para hoy tener un millon de € (hoy es 14/07/2025)               │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # First, let's find a website that could provide historical Bitcoin prices by year or date.
#   url = "https://www.coindesk.com/price/bitcoin"  # This site has Bitcoin price charts and history
#
#   page_content = visit_webpage(url)
#   print(page_content[:2000])  # Print a snippet of the page content to check if historical data is present
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Bitcoin (BTC) Price | BTC to USD Price and Live Chart
#
# [BTC
#
# $120,286.64
#
# +
#
# 1.09%](/price/bitcoin "View price details")[ETH
#
# $3,006.31
#
# +
#
# 0.57%](/price/ethereum "View price details")[XRP
#
# $2.9234
#
# +
#
# 2.78%](/price/xrp "View price details")[USDT
#
# $1.0002
#
# +
#
# 0.01%](/price/tether "View price details")[BNB
#
# $691.35
#
# -
#
# 0.16%](/price/binance-coin "View price details")[SOL
#
# $163.11
#
# +
#
# 0.46%](/price/solana "View price details")[USDC
#
# $0.9999
#
# +
#
# 0.02%](/price/usd-coin "View price details")[DOGE
#
# $0.1977
#
# -
#
# 1.53%](/price/dogecoin "View price details")[TRX
#
# $0.3017
#
# -
#
# 0.46%](/price/tron "View price details")[ADA
#
# $0.7332
#
# -
#
# 1.40%](/price/cardano "View price details")[HYPE
#
# $47.41
#
# -
#
# 3.15%](/price/hype "View price details")[XLM
#
# $0.4456
#
# -
#
# 5.61%](/price/xlm "View price details")[SUI
#
# $3.8492
#
# +
#
# 10.36%](/price/sui "View price details")[LINK
#
# $15.82
#
# -
#
# 0.15%](/price/chainlink "View price details")[HBAR
#
# $0.2372
#
# +
#
# 0.05%](/price/hbar "View price details")[BCH
#
# $503.52
#
# -
#
# 1.00%](/price/bitcoin-cash "View price details")[WBT
#
# $45.71
#
# -
#
# 0.84%](/price/wbt "View price details")[AVAX
#
# $21.30
#
# -
#
# 0.61%](/price/avax "View price details")[LEO
#
# $8.9954
#
# -
#
# 0.37%](/price/unus-sed-leo "View price details")[SHIB
#
# $0.0₄1326
#
# -
#
# 0.70%](/price/shiba-inu "View price details")
#
# Ad
#
# * [News](/)
#
#   Back to menu
#
#   News
#   + [Markets](/markets)
#   + [Finance](/business)
#   + [Tech](/tech)
#   + [Policy](/policy)
#   + [Focus](/focus)
# * [Prices](/price)
#
#   Back to menu
#
#   Prices
# * [Data](https://data.coindesk.com/)
#
#   Back to menu
#
#   Data
#   + [Trade Data](https://data.coindesk.com/trade-data)
#   + [Derivatives](https://data.coindesk.com/derivatives)
#   + [Order Book Data](https://data.coindesk.com/order-book)
#   + [On-Chain Data](https://data.coindesk.com/on-chain-data)
#   + [API](https://developers.coindesk.com/documentation)
#   + [Research & Insights](https://data.coindesk.com/reports)
#   + [Data Catalogue](https://data.coindesk.com/data-catalogue)
#   + [AI & Machine Learning](https://data.coindesk
#
# Out: None
# [Step 1: Duration 4.91 seconds| Input tokens: 1,972 | Output tokens: 194]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   historic_prices_url = "https://www.coindesk.com/price/bitcoin/historical"
#   historic_content = visit_webpage(historic_prices_url)
#   print(historic_content[:2000])  # Inspect the first part of the historic data page content
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 504 Server Error: Gateway Timeout for url:
# https://www.coindesk.com/price/bitcoin/historical
#
# Out: None
# [Step 2: Duration 18.36 seconds| Input tokens: 5,003 | Output tokens: 358]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   coingecko_hist_url = "https://www.coingecko.com/en/coins/bitcoin/historical_data/usd"
#   hist_page = visit_webpage(coingecko_hist_url)
#   print(hist_page[:2000])  # Print the first part to check if historical prices are available
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 403 Client Error: Forbidden for url: https://www.coingecko.com/en/coins/bitcoin
#
# Out: None
# [Step 3: Duration 2.47 seconds| Input tokens: 8,337 | Output tokens: 491]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   wiki_url = "https://en.wikipedia.org/wiki/Bitcoin_price"
#   wiki_content = visit_webpage(wiki_url)
#   print(wiki_content[:3000])  # Print the beginning of the content to identify any historical price tables or
#   data
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Bitcoin_price
#
# Out: None
# [Step 4: Duration 2.42 seconds| Input tokens: 11,945 | Output tokens: 640]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   wiki_bitcoin_url = "https://en.wikipedia.org/wiki/Bitcoin"
#   bitcoin_page = visit_webpage(wiki_bitcoin_url)
#   print(bitcoin_page[:3000])  # Inspect start of the Bitcoin Wikipedia page for historical price info
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Bitcoin - Wikipedia
#
# [Jump to content](#bodyContent)
#
# Main menu
#
# Main menu
#
# move to sidebar
# hide
#
# Navigation
#
# * [Main page](/wiki/Main_Page "Visit the main page [z]")
# * [Contents](/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")
# * [Current events](/wiki/Portal:Current_events "Articles related to current events")
# * [Random article](/wiki/Special:Random "Visit a randomly selected article [x]")
# * [About Wikipedia](/wiki/Wikipedia:About "Learn about Wikipedia and how it works")
# * [Contact us](//en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")
#
# Contribute
#
# * [Help](/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")
# * [Learn to edit](/wiki/Help:Introduction "Learn how to edit Wikipedia")
# * [Community portal](/wiki/Wikipedia:Community_portal "The hub for editors")
# * [Recent changes](/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")
# * [Upload file](/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")
# * [Special pages](/wiki/Special:SpecialPages)
#
# [![](/static/images/icons/wikipedia.png)
#
# ![Wikipedia](/static/images/mobile/copyright/wikipedia-wordmark-en.svg)
# ![The Free Encyclopedia](/static/images/mobile/copyright/wikipedia-tagline-en.svg)](/wiki/Main_Page)
#
# [Search](/wiki/Special:Search "Search Wikipedia [f]")
#
# Search
#
# Appearance
#
# *
# [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=e
# n)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Bitcoin "You are encouraged to create an
# account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Bitcoin "You're encouraged to log in; however, it's not
# mandatory. [o]")
#
# Personal tools
#
# *
# [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=e
# n)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Bitcoin "You are encouraged to create an
# account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Bitcoin "You're encouraged to log in; however, it's not
# mandatory. [o]")
#
# Pages for logged out editors [learn more](/wiki/Help:Introduction)
#
# * [Contributions](/wiki/Special:MyContributions "A list of edits made from this IP address [y]")
# * [Talk](/wiki/Special:MyTalk "Discussion about edits from this IP address [n]")
#
# Contents
# --------
#
# move to sidebar
# hide
#
# * [(Top)](#)
# * [1
#   History](#History)
#
#   Toggle History subsection
#   + [1.1
#     Background](#Background)
#   + [1.2
#     2008–2009: Creation](#2008–2009:_Creation)
#   + [1.3
#     2010–2012: Early growth](#2010–2012:_Early_growth)
#   + [1.4
#     2013–2014: First regulatory actions](#2013–2014:_First_regulatory_actions)
#   + [1.5
#     2015–2019](#2015–2019)
#   + [1.6
#     2020–present](#2020–present)
# * [2
#   Design](#Design)
#
#   Toggle Design subsection
#   + [2.1
#     Units and divisibility](#Units_and_divisibility)
#   + [2.2
#     Blockchain
#
# Out: None
# [Step 5: Duration 2.40 seconds| Input tokens: 15,832 | Output tokens: 750]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content="Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content="Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # We have the page content as 'bitcoin_page'. I will try to extract price mentions by looking for years and
#   prices.
#   import re
#
#   # Extract lines containing years (between 2009 and 2025) and prices in $ or € form
#   lines = bitcoin_page.split('\n')
#
#   years = list(range(2009, 2026))
#   price_data = []
#
#   for line in lines:
#       # Search for year in line
#       year_found = None
#       for y in years:
#           if str(y) in line:
#               year_found = y
#               break
#       if year_found:
#           # Look for price mentions
#           # Prices might be mentioned as $ or € followed by numbers
#           prices = re.findall(r'(\$|€)\s?([0-9.,]+)', line)
#           if prices:
#               price_data.append((year_found, prices, line.strip()))
#
#   print(price_data)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# []
#
# Out: None
# [Step 6: Duration 3.69 seconds| Input tokens: 20,779 | Output tokens: 1,013]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#
#   # Extract sub-sections by year headings in markdown style '##' or '###' or with year in heading format
#   # We'll find sections starting with year and extract content below them to find mentions of price or worth
#
#   year_contents = {}
#   current_year = None
#   capture = False
#   buffer = []
#
#   for line in bitcoin_page.split('\n'):
#       # Identify line that likely starts a year section (just the year as heading or contains year)
#       if re.match(r'.*20(0[9]|1[0-9]|2[0-5]).*', line):
#           # Save previous year content
#           if current_year and buffer:
#               year_contents[current_year] = '\n'.join(buffer)
#           # Start new year capture
#           current_year = re.search(r'20(0[9]|1[0-9]|2[0-5])', line).group()
#           buffer = []
#           capture = True
#       elif capture:
#           # Keep capturing lines for current year until next year heading encountered
#           if line.strip().startswith('==') or line.strip().startswith('='):
#               # End capture at new major section likely
#               if current_year and buffer:
#                   year_contents[current_year] = '\n'.join(buffer)
#               current_year = None
#               capture = False
#           else:
#               buffer.append(line)
#
#   # Add last one if still capturing
#   if current_year and buffer:
#       year_contents[current_year] = '\n'.join(buffer)
#
#
#   # Now let's see what content we got per each year section
#   for year, content in year_contents.items():
#       print(f"Year: {year}, Content snippet: {content[:300]}\n---\n")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Year: 2009, Content snippet:
# Hidden categories:
#
# * [Webarchive template wayback links](/wiki/Category:Webarchive_template_wayback_links "Category:Webarchive
# template wayback links")
# * [CS1: long volume value](/wiki/Category:CS1:_long_volume_value "Category:CS1: long volume value")
# * [Articles with short description](/wiki/Cate
# ---
#
# Year: 2010, Content snippet:   + [1.4
# ---
#
# Year: 2013, Content snippet:   + [1.5
# ---
#
# Year: 2015, Content snippet: | Other | * [IdRef](https://www.idref.fr/175289379) * [Yale
# LUX](https://lux.collections.yale.edu/view/concept/83c10b93-7d69-470e-adf8-cfd507a29b16) |
#
# [Portals](/wiki/Wikipedia:Contents/Portals "Wikipedia:Contents/Portals"):
#
# * [![icon](//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Emblem-mon
# ---
#
# Year: 2020, Content snippet: * [2
#   Design](#Design)
#
#   Toggle Design subsection
#   + [2.1
#     Units and divisibility](#Units_and_divisibility)
#   + [2.2
#     Blockchain](#Blockchain)
#   + [2.3
#     Addresses and transactions](#Addresses_and_transactions)
#   + [2.4
#     Mining](#Mining)
#   + [2.5
#     Privacy and fungibility](#Privacy_a
# ---
#
# Year: 2025, Content snippet: * Text is available under the [Creative Commons Attribution-ShareAlike 4.0
# License](/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# "Wikipedia:Text of the Creative Commons Attribution-ShareAlike 4.0 International License");
#   additional terms may apply.
# ---
#
# Year: 2023, Content snippet: * [Pages using Sister project links with wikidata namespace
# mismatch](/wiki/Category:Pages_using_Sister_project_links_with_wikidata_namespace_mismatch "Category:Pages using
# Sister project links with wikidata namespace mismatch")
#
# ---
#
# Year: 2017, Content snippet: * [All Wikipedia articles written in American
# English](/wiki/Category:All_Wikipedia_articles_written_in_American_English "Category:All Wikipedia articles written
# in American English")
# * [Articles containing Japanese-language text](/wiki/Category:Articles_containing_Japanese-language_text
# "Category:A
# ---
#
# Year: 2024, Content snippet: * [All articles containing potentially dated
# statements](/wiki/Category:All_articles_containing_potentially_dated_statements "Category:All articles containing
# potentially dated statements")
# ---
#
#
# Out: None
# [Step 7: Duration 7.53 seconds| Input tokens: 26,252 | Output tokens: 1,482]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 8 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Approximate historical BTC prices in USD (rounded, public info):
#   # 2010: $0.1
#   # 2012: $5
#   # 2015: $300
#   # 2017: $1000 (start) to $20,000 (end), let's use $4000 average
#   # 2020: $7,000
#   # 2025 (today): $120,000 (from earlier page)
#
#   btc_prices_usd = {
#       2010: 0.1,
#       2012: 5,
#       2015: 300,
#       2017: 4000,
#       2020: 7000,
#       2025: 120000
#   }
#
#   # EUR/USD conversion approximate for calculation
#   eur_usd_rate = 1.1
#
#   # Convert prices to euros
#   btc_prices_eur = {year: price / eur_usd_rate for year, price in btc_prices_usd.items()}
#
#   # Calculate for each year how many BTC 1000€ would have bought
#   btc_bought = {year: 1000 / price for year, price in btc_prices_eur.items() if year != 2025}
#
#   # Calculate value in 2025 for BTC bought in each year
#   value_2025 = {year: btc_bought[year] * btc_prices_eur[2025] for year in btc_bought}
#
#   print("Values in 2025 for 1000€ invested in given years:")
#   for year in sorted(value_2025):
#       print(f"Year {year}: {value_2025[year]:,.2f} €")
#
#   # Find the earliest year where value >= 1,000,000 €
#   years_meeting_goal = [year for year, value in value_2025.items() if value >= 1_000_000]
#   earliest_year = min(years_meeting_goal) if years_meeting_goal else None
#   print(f"Earliest year to have invested 1000€ to get >= 1,000,000€ by 2025: {earliest_year}")
#
#   earliest_year
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Values in 2025 for 1000€ invested in given years:
# Year 2010: 1,200,000,000.00 €
# Year 2012: 24,000,000.00 €
# Year 2015: 400,000.00 €
# Year 2017: 30,000.00 €
# Year 2020: 17,142.86 €
# Earliest year to have invested 1000€ to get >= 1,000,000€ by 2025: 2010
#
# Out: 2010
# [Step 8: Duration 9.40 seconds| Input tokens: 33,243 | Output tokens: 2,153]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 9 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='final_an...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='final_an...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Error in code parsing:
# Your code snippet is invalid, because the regex pattern <code>(.*?)</code> was not found in it.
# Here is your code snippet:
# final_answer("Para tener un millón de euros en 2025 comprando Bitcoin con 1000€, deberías haber comprado en el año
# 2010.")</code>
# It seems like you're trying to return the final answer, you can do it as follows:
# <code>
# final_answer("YOUR FINAL ANSWER HERE")
# </code>
# Make sure to provide correct code blobs.
# [Step 9: Duration 0.82 seconds| Input tokens: 41,542 | Output tokens: 2,185]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 10 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='<code>\n...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='<code>\n...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Para tener un millón de euros en 2025 comprando Bitcoin con 1000€, deberías haber comprado en el
#   año 2010.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Para tener un millón de euros en 2025 comprando Bitcoin con 1000€, deberías haber comprado en el año
# 2010.
# [Step 10: Duration 0.87 seconds| Input tokens: 50,022 | Output tokens: 2,223]
# 'Para tener un millón de euros en 2025 comprando Bitcoin con 1000€, deberías haber comprado en el año 2010.'

# %%
agent.run("Precio actual de bitcoin?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Precio actual de bitcoin?                                                                                       │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Visit a popular Bitcoin price website to read its content and extract the price later
#   bitcoin_price_page = visit_webpage("https://www.coindesk.com/price/bitcoin")
#   print(bitcoin_price_page)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Bitcoin (BTC) Price | BTC to USD Price and Live Chart
#
# [BTC
#
# $111,379.01
#
# +
#
# 1.76%](/price/bitcoin "View price details")[ETH
#
# $2,638.64
#
# +
#
# 3.75%](/price/ethereum "View price details")[USDT
#
# $1.0001
#
# -
#
# 0.03%](/price/tether "View price details")[XRP
#
# $2.4226
#
# +
#
# 0.96%](/price/xrp "View price details")[BNB
#
# $680.64
#
# +
#
# 3.15%](/price/binance-coin "View price details")[SOL
#
# $178.06
#
# +
#
# 3.78%](/price/solana "View price details")[USDC
#
# $0.9996
#
# -
#
# 0.00%](/price/usd-coin "View price details")[DOGE
#
# $0.2394
#
# +
#
# 3.84%](/price/dogecoin "View price details")[ADA
#
# $0.8018
#
# +
#
# 4.95%](/price/cardano "View price details")[TRX
#
# $0.2769
#
# +
#
# 2.13%](/price/tron "View price details")[SUI
#
# $3.8656
#
# -
#
# 0.78%](/price/sui "View price details")[LINK
#
# $16.68
#
# +
#
# 4.47%](/price/chainlink "View price details")[AVAX
#
# $25.13
#
# +
#
# 8.21%](/price/avax "View price details")[HYPE
#
# $33.07
#
# +
#
# 13.44%](/price/hype "View price details")[XLM
#
# $0.3033
#
# +
#
# 3.02%](/price/xlm "View price details")[SHIB
#
# $0.0₄1522
#
# +
#
# 3.56%](/price/shiba-inu "View price details")[HBAR
#
# $0.2042
#
# +
#
# 2.25%](/price/hbar "View price details")[BCH
#
# $436.44
#
# +
#
# 5.75%](/price/bitcoin-cash "View price details")[LEO
#
# $8.8682
#
# +
#
# 0.99%](/price/unus-sed-leo "View price details")[TON
#
# $3.1569
#
# +
#
# 2.64%](/price/toncoin "View price details")
#
# * [News](/)
#
#   Back to menu
#
#   News
#   + [Markets](/markets)
#   + [Finance](/business)
#   + [Tech](/tech)
#   + [Policy](/policy)
#   + [Focus](/focus)
# * [Prices](/price)
#
#   Back to menu
#
#   Prices
# * [Data](https://data.coindesk.com/)
#
#   Back to menu
#
#   Data
#   + [Trade Data](https://data.coindesk.com/trade-data)
#   + [Derivatives](https://data.coindesk.com/derivatives)
#   + [Order Book Data](https://data.coindesk.com/order-book)
#   + [On-Chain Data](https://data.coindesk.com/on-chain-data)
#   + [API](https://developers.coindesk.com/documentation)
#   + [Research & Insights](https://data.coindesk.com/reports)
#   + [Data Catalogue](https://data.coindesk.com/data-catalogue)
#   + [AI & Machine Learning](https://data.coindesk.com/ai-machine-learning)
# * [Indices](https://indices.coindesk.com/)
#
#   Back to menu
#
#   Indices
#   + [Multi-Asset Indices](https://indices.coindesk.com/multi-asset-indices)
#   + [Reference Rates](https://indices.coindesk.com/reference-rates)
#   + [Strategies and Services](https://indices.coindesk.com/strategies-and-services)
#   + [API](https://developers.coindesk.com/documentation)
#   + [Insights & Announcements](https://indices.coindesk.com/insights-and-announcements)
#   + [Documentation & Governance](https://indices.coindesk.com/documentation-and-governance)
# * [Research](https://data.coindesk.com/reports)
#
#   Back to menu
#
#   Research
# * [Events](https://events.coindesk.com/)
#
#   Back to menu
#
#   Events
#   + [Consensus 2025](https://consensus2025.coindesk.com/)
#   + [Consensus 2025 Coverage](https://www.coindesk.com/consensus-toronto-2025-coverage)
# * [Sponsored](/sponsored-content)
#
#   Back to menu
#
#   Sponsored
#   + [Thought Leadership](/sponsored-content)
#   + [Press Releases](/press-release)
#   + [CoinW](/sponsored-content/hub/coinw)
#   + [MEXC](/sponsored-content/hub/MEXC)
#   + [Phemex](/sponsored-content/hub/Phemex)
#   + [Advertise](/advertise)
#
# * [Videos](/videos)
#
#   Back to menu
#
#   Videos
#   + [CoinDesk Daily](/videos/coindesk-daily)
#   + [Shorts](/videos/shorts)
#   + [Editor's Picks](/videos/editors-picks)
# * [Podcasts](/podcasts)
#
#   Back to menu
#
#   Podcasts
#   + [CoinDesk Podcast Network](/podcasts/coindesk-podcast-network)
#   + [Markets Daily](/podcasts/markets-daily)
#   + [Gen C](/podcasts/generation-c)
#   + [Unchained with Laura Shin](/podcasts/unchained)
#   + [The Mining Pod](/podcasts/coindesk-podcast-network)
# * [Newsletters](/newsletters)
#
#   Back to menu
#
#   Newsletters
#   + [The Node](/newsletters/the-node)
#   + [Crypto Daybook Americas](/newsletters/daybook-us)
#   + [State of Crypto](/newsletters/state-of-crypto)
#   + [Crypto Long & Short](/newsletters/crypto-long-short)
#   + [Crypto for Advisors](/newsletters/crypto-for-advisors)
# * [Webinars & Events](https://events.coindesk.com/)
#
#   Back to menu
#
#   Webinars & Events
#   + [Consensus 2025](https://consensus2025.coindesk.com/)
#   + [Policy & Regulation Conference](https://policy-regulation.coindesk.com/)
#
# English
#
# Select Language
#
# [English en](/price/bitcoin)[Українська uk](/uk/price/bitcoin)[Русский ru](/ru/price/bitcoin)[Português
# pt-br](/pt-br/price/bitcoin)[Filipino fil](/fil/price/bitcoin)[Italiano it](/it/price/bitcoin)[Español
# es](/es/price/bitcoin)[Français fr](/fr/price/bitcoin)
#
# [![Logo](/_next/image?url=https%3A%2F%2Fcoindesk-next-gvxggviul-coindesk.vercel.app%2F_next%2Fstatic%2Fmedia%2Fcoin
# desk-logo.68661da3.png&w=384&q=75)](/)
#
# * [News](/)
# * [Prices](/price)
# * [Data](https://data.coindesk.com/)
# * [Indices](https://indices.coindesk.com/)
# * [Research](https://data.coindesk.com/reports)
# * [Events](https://events.coindesk.com/)
# * [Sponsored](/sponsored-content)
# * [Sign
# In](https://www.coindesk.com/auth/login?returnTo=https%3A%2F%2Fwww.coindesk.com%2Fprice%2Fbitcoin&reg_module=naviga
# tion "Sign in to your CoinDesk account")
# * [Sign
# Up](https://www.coindesk.com/auth/login?returnTo=https%3A%2F%2Fwww.coindesk.com%2Fprice%2Fbitcoin&screen_hint=signu
# p&reg_module=navigation "Sign up for a free CoinDesk account")
#
# ![](https://resources.cryptocompare.com/asset-management/1/1659708726266.png)
#
# BTC
#
# Bitcoin
# =======
#
# $111,328.45
#
# 2.45%
#
# Buy / SellGet Crypto
#
# Market Cap. #1
#
# $2,211,915,474,741
#
# Volume (24h) #1
#
# $35,275,546,702
#
# Supply (Circ. / Total / Max)
#
# 19.87M  / 19.87M  / 21M
#
# * [Overview](/price/bitcoin)
# * [Platforms](/price/bitcoin/platforms)
# * [News](/price/bitcoin/news)
#
# BasicAdvanced
#
# Open
#
# -
#
# High
#
# -
#
# Low
#
# -
#
# Vol.
#
# -
#
# 1H
#
# 24H
#
# 7D
#
# 1M
#
# 1Y
#
# All
#
# ![coindesk-loading-spinner](/_next/image?url=https%3A%2F%2Fcoindesk-next-gvxggviul-coindesk.vercel.app%2F_next%2Fst
# atic%2Fmedia%2Fcoindesk-spinner.bb1054ee.svg&w=256&q=75)
#
# 1H
#
# 24H
#
# 7D
#
# 1M
#
# 1Y
#
# All
#
# Need more data?[Explore CoinDesk's API](https://developers.cryptocompare.com/documentation/data-api/introduction)
#
# Market Cap. #1
#
# $2,211,915,474,741
#
# Volume (24h) #1
#
# $35,275,546,702
#
# Supply (Circ. / Total / Max)
#
# 19.87M  / 19.87M  / 21M
#
# Launch Date
#
# 2009-01-03
#
# Block Number
#
# 897,888
#
# Block Reward
#
# 3.13
#
# Last Block Size
#
# 1,591,288
#
# Network H/s
#
# 926452247.1T
#
# 2009-01-03
#
# Launch Date
#
# 897,888
#
# Block Number
#
# 3.13
#
# Block Reward
#
# 1,591,288
#
# Last Block Size
#
# 926452247.1T
#
# Network H/s
#
# Bitcoin Price Converter
# -----------------------
#
# ![Bitcoin](/_next/image?url=https%3A%2F%2Fresources.cryptocompare.com%2Fasset-management%2F1%2F1659708726266.png&w=
# 96&q=75)
#
# Bitcoin Information
# -------------------
#
# ### Resources
#
# |  |  |
# | --- | --- |
# | Websites |
# [Website](https://bitcoin.org)[Whitepaper](https://resources.cryptocompare.com/asset-management/1/1659709016925.pdf
# )[Blog](https://bitcoin.org/en/blog) |
# | Block Explorers | [blockchain.info](https://blockchain.info/)... |
# | Code Repositories | [github.com/bitcoin/bitcoin](https://github.com/bitcoin/bitcoin
# "https://github.com/bitcoin/bitcoin") |
# | Hashing Algorithms | SHA-256 |
# | Supported Standards | BRC-20  ARC-20  Runes |
# | Industries | Payment |
# | Communities | [www.reddit.com](https://www.reddit.com/r/Bitcoin)... |
#
# Bitcoin Supported Platforms
# ---------------------------
#
# | Trading As | Token Standard | Built On | Smart Contract Address | Launch Date |
# | --- | --- | --- | --- | --- |
# | 1WBTC | HRC20 | ONE |
# [0x3095c7557bcb296ccc6e363de01b760ba031f2d9](https://explorer.harmony.one/address/0x3095c7557bcb296ccc6e363de01b760
# ba031f2d9) | 2020-10-16 |
# | ABWBTC | ERC20 | ARB |
# [0x2f2a2543B76A4166549F7aaB2e75Bef0aefC5B0f](https://arbiscan.io/token/0x2f2a2543B76A4166549F7aaB2e75Bef0aefC5B0f)
# | 2021-06-16 |
# | BBTC | ERC20 | ETH |
# [0x9be89d2a4cd102d8fecc6bf9da793be995c22541](https://etherscan.io/token/0x9be89d2a4cd102d8fecc6bf9da793be995c22541)
# | 2020-10-23 |
# | BTCAB | ERC20 | AVAX |
# [0x152b9d0FdC40C096757F570A51E494bd4b943E50](https://snowtrace.io/token/0x152b9d0FdC40C096757F570A51E494bd4b943E50)
# | 2022-05-19 |
# | BTCB | BEP2 | BNB | [BTCB-1DE](https://explorer.bnbchain.org/asset/BTCB-1DE) | 2019-06-17 |
#
# [View all](/price/bitcoin/platforms)
#
# About Bitcoin
# -------------
#
# Bitcoin is a decentralized cryptocurrency that uses peer-to-peer technology and a blockchain to record
# transactions. It was created by Satoshi Nakamoto and the first block was mined on January 3, 2009. Bitcoin
# transactions are recorded on a blockchain, which is a distributed ledger that can be accessed by anyone to verify
# transactions. Transactions are verified by miners, who are rewarded with a set amount of Bitcoin and transaction
# fees. The supply of Bitcoin is limited to 21 million coins and it is divisible to eight decimal places. A wallet is
# needed to use Bitcoin and it consists of a public key, which is used to send and receive payments, and a private
# key, which is used to control the wallet. Bitcoin can be used for a variety of purposes, including everyday
# transactions, as a store of value, or for investment.
#
# What is Bitcoin?
# ----------------
#
# Bitcoin is a decentralized digital currency that uses
# [cryptography](https://www.coindesk.com/learn/what-is-cryptography) to secure transactions and control the supply
# of new coins. It operates on a peer-to-peer network, where every transaction is recorded on a public ledger called
# the [blockchain](https://www.coindesk.com/learn/what-is-blockchain-technology). As the first digital currency to
# enable direct transfers of value without intermediaries, Bitcoin has pioneered a new approach to money. Today, it
# functions as both a medium of exchange and a store of value, influencing global finance and inspiring many other
# digital currencies.
#
# Each bitcoin is made up of 100 million
# [satoshis](https://www.coindesk.com/learn/what-is-a-satoshi-understanding-the-smallest-unit-of-bitcoin/), making it
# divisible up to eight decimal places. This means that anyone can purchase a fraction of a bitcoin with as little as
# one U.S. dollar.
#
# ---
#
# So, who created Bitcoin?
# ------------------------
#
# That’s a question that has intrigued many. Bitcoin was created by an unknown person or group using the name
# [Satoshi Nakamoto](https://www.coindesk.com/learn/who-is-satoshi-nakamoto). In 2008, Satoshi published a whitepaper
# titled “[Bitcoin: A Peer-to-Peer Electronic Cash System](https://bitcoin.org/bitcoin.pdf)” that outlined a method
# for sending money directly between individuals without relying on central authorities. The network came to life in
# January 2009 with the mining of the [genesis block](https://www.coindesk.com/learn/the-genesis-block), marking
# Bitcoin’s official launch. Despite numerous investigations, Satoshi Nakamoto’s [true identity remains a
# mystery](https://www.coindesk.com/coindesk-news/2024/12/10/satoshi-nakamoto-the-mystery-that-probably-will-never-be
# -solved).
#
# ---
#
# Then, who manages Bitcoin?
# --------------------------
#
# ---
#
# How does Bitcoin work?
# ----------------------
#
# ---
#
# How does Bitcoin mining work?
# -----------------------------
#
# ---
#
# What are Bitcoin Halvings?
# --------------------------
#
# ---
#
# Why Does Bitcoin Appreciate in Value?
# -------------------------------------
#
# ---
#
# Bitcoin (BTC) Price
# -------------------
#
# ---
#
# What is Bitcoin’s All-Time High?
# --------------------------------
#
# ---
#
# How to Buy Bitcoin
# ------------------
#
# ---
#
# How is Bitcoin Stored?
# ----------------------
#
# ---
#
# What is Bitcoin’s Energy Consumption?
# -------------------------------------
#
# ---
#
# What is a Bitcoin ETF?
# ----------------------
#
# ---
#
# How to Invest in a Bitcoin ETF
# ------------------------------
#
# ---
#
# ---
#
# About
#
# * [About Us](/about)
# * [Masthead](/masthead)
# * [Careers](https://bullish.wd3.myworkdayjobs.com/CoinDesk)
# * [CoinDesk News](/coindesk-news)
# * [Crypto API Documentation](https://developers.coindesk.com/documentation/data-api/introduction)
#
# Contact
#
# * [Contact Us](/contact-us)
# * [Accessibility](/accessibility-help)
# * [Advertise](/advertise)
# * [Sitemap](/sitemap)
# * [System Status](https://status.coindesk.com)
#
# DISCLOSURE & POLICES
#
# CoinDesk is an
# [award-winning](/business/2023/02/20/coindesk-wins-a-polk-award-a-top-journalism-prize-for-explosive-ftx-coverage)
# media outlet that covers the cryptocurrency industry. Its journalists abide by a strict set of [editorial
# policies](/ethics). CoinDesk has adopted a set of principles aimed at ensuring the integrity, editorial
# independence and freedom from bias of its publications. CoinDesk is part of the Bullish group, which owns and
# invests in digital asset businesses and digital assets. CoinDesk employees, including journalists, may receive
# Bullish group equity-based compensation. Bullish was incubated by technology investor Block.one.
#
# [Ethics](/ethics)[Privacy](/privacy)[Terms of Use](/terms)Cookie Settings[Do Not Sell My Info](/privacy#dnsmpi)
#
# ---
#
# © 2025 CoinDesk, Inc.
#
# [X icon](https://twitter.com/coindesk)
#
# Out: None
# [Step 1: Duration 3.42 seconds| Input tokens: 1,994 | Output tokens: 140]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bitcoin_current_price = "$111,328.45"
#   final_answer(bitcoin_current_price)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: $111,328.45
# [Step 2: Duration 1.60 seconds| Input tokens: 8,034 | Output tokens: 202]
# '$111,328.45'

# %%
agent.run("Cual fue la razón del apagon del mes de abril en españa?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Cual fue la razón del apagon del mes de abril en españa?                                                        │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_result = visit_webpage("https://www.google.com/search?q=apagón+abril+España+razón")
#   print(search_result[:1000])  # Print the first 1000 characters to check the search results content
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Google Search
#
# Please click [here](/httpservice/retry/enablejs?sei=2G91aOHkNr3hwN4PubqK0Ac) if you are not redirected within a few
# seconds.
#
# If you're having trouble accessing Google Search, please [click
# here](/search?q=apag%C3%B3n+abril+Espa%C3%B1a+raz%C3%B3n&sca_esv=b9187f4daeb51a28&ie=UTF-8&emsg=SG_REL&sei=2G91aOHk
# Nr3hwN4PubqK0Ac), or send [feedback](https://support.google.com/websearch).
#
# Out: None
# [Step 1: Duration 2.33 seconds| Input tokens: 1,956 | Output tokens: 112]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Trying a news source for Spain blackout in April
#   news_url = "https://elpais.com/search/apagon abril"
#   news_page = visit_webpage(news_url)
#   print(news_page[:2000])  # Print first 2000 characters to extract relevant info
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 404 Client Error: Not Found for url: https://elpais.com/search/apagon%20abril/
#
# Out: None
# [Step 2: Duration 4.00 seconds| Input tokens: 4,274 | Output tokens: 257]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   wiki_url = "https://es.wikipedia.org/wiki/Apagón_en_España"
#   wiki_content = visit_webpage(wiki_url)
#   print(wiki_content[:2000])  # Read the start of the page to see if relevant info is present
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Apagón en la península ibérica de 2025 - Wikipedia, la enciclopedia libre
#
# [Ir al contenido](#bodyContent)
#
# Menú principal
#
# Menú principal
#
# mover a la barra lateral
# ocultar
#
# Navegación
#
# * [Portada](/wiki/Wikipedia:Portada "Visitar la página principal [z]")
# * [Portal de la comunidad](/wiki/Portal:Comunidad "Acerca del proyecto, lo que puedes hacer, dónde encontrar
# información")
# * [Actualidad](/wiki/Portal:Actualidad "Encuentra información de contexto sobre acontecimientos actuales")
# * [Cambios recientes](/wiki/Especial:CambiosRecientes "Lista de cambios recientes en la wiki [r]")
# * [Páginas nuevas](/wiki/Especial:P%C3%A1ginasNuevas)
# * [Página aleatoria](/wiki/Especial:Aleatoria "Cargar una página al azar [x]")
# * [Ayuda](/wiki/Ayuda:Contenidos "El lugar para aprender")
# * [Notificar un error](/wiki/Wikipedia:Informes_de_error)
# * [Páginas especiales](/wiki/Especial:P%C3%A1ginasEspeciales)
#
# [![](/static/images/icons/wikipedia.png)
#
# ![Wikipedia](/static/images/mobile/copyright/wikipedia-wordmark-en.svg)
# ![La enciclopedia libre](/static/images/mobile/copyright/wikipedia-tagline-es.svg)](/wiki/Wikipedia:Portada)
#
# [Buscar](/wiki/Especial:Buscar "Buscar en este wiki [f]")
#
# Buscar
#
# Apariencia
#
# *
# [Donaciones](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=es.wikipedia.org&usela
# ng=es)
# * [Crear una
# cuenta](/w/index.php?title=Especial:Crear_una_cuenta&returnto=Apag%C3%B3n+en+la+pen%C3%ADnsula+ib%C3%A9rica+de+2025
# "Te recomendamos crear una cuenta e iniciar sesión; sin embargo, no es obligatorio")
# * [Acceder](/w/index.php?title=Especial:Entrar&returnto=Apag%C3%B3n+en+la+pen%C3%ADnsula+ib%C3%A9rica+de+2025 "Te
# recomendamos iniciar sesión, aunque no es obligatorio [o]")
#
# Herramientas personales
#
# *
# [Donaciones](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=es.wikipedia.org&usela
# ng=es)
# * [Crear una
# cuenta](/w/index.php?title=Especial:Crear_una_cuenta&returnto=Apag%C3%B3n+en+la+pen%C3%ADnsula+ib%C3%A9rica+de+2025
# "Te rec
#
# Out: None
# [Step 3: Duration 3.82 seconds| Input tokens: 6,873 | Output tokens: 412]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   news_search_url = "https://www.google.com/search?q=apagón+abril+España+noticias"
#   news_search_page = visit_webpage(news_search_url)
#   print(news_search_page[:2000])  # Extract some content for relevant info
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Google Search
#
# Please click [here](/httpservice/retry/enablejs?sei=5291aNT3JPPAp84P46jH-Qo) if you are not redirected within a few
# seconds.
#
# If you're having trouble accessing Google Search, please [click
# here](/search?q=apag%C3%B3n+abril+Espa%C3%B1a+noticias&sca_esv=b9187f4daeb51a28&ie=UTF-8&emsg=SG_REL&sei=5291aNT3JP
# PAp84P46jH-Qo), or send [feedback](https://support.google.com/websearch).
#
# Out: None
# [Step 4: Duration 6.86 seconds| Input tokens: 10,349 | Output tokens: 561]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Trying a direct search URL on a major Spanish news website (El Mundo)
#   elmundo_url = "https://www.elmundo.es/buscador/archivo.html?q=apag%C3%B3n%20abril%20espa%C3%B1a"
#   elmundo_page = visit_webpage(elmundo_url)
#   print(elmundo_page[:2000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error fetching the webpage: 404 Client Error: Not Found for url:
# https://www.elmundo.es/buscador/archivo.html?q=apag%C3%B3n%20abril%20espa%C3%B1a
#
# Out: None
# [Step 5: Duration 3.81 seconds| Input tokens: 14,221 | Output tokens: 732]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   lavanguardia_url = "https://www.lavanguardia.com"
#   lavanguardia_homepage = visit_webpage(lavanguardia_url)
#   print(lavanguardia_homepage[:2000])  # Print a sample to extract keywords and articles headlines
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Últimas noticias, actualidad y última hora en Catalunya, España y el mundo
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6398301&cs_ucfr=1&cv=2.0&cj=1)
#
# ![](https://www.facebook.com/tr?id=316167066837274&ev=PageView&noscript=1/)
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6398301&cs_ucfr=1&cv=2.0&cj=1)
#
# * [Torre
# Pacheco](https://www.lavanguardia.com/politica/20250714/10885193/nuevos-altercados-grupos-ultras-e-inmigrantes-torr
# e-pacheco.html)
# * [Borja Sémper](https://www.lavanguardia.com/politica/20250714/10887054/borja-semper-anuncia-cancer.html)
# * [Fútbol hoy](https://www.lavanguardia.com/deportes/resultados)
# * [Calendario laboral](https://www.lavanguardia.com/calendario/)
# * [Comprobar lotería](https://www.lavanguardia.com/comprobar-loteria/)
# * [Lotería Nacional](https://www.lavanguardia.com/comprobar-loteria/loteria-nacional/)
# * [Bonoloto](https://www.lavanguardia.com/comprobar-loteria/bonoloto/)
# * [Primitiva](https://www.lavanguardia.com/comprobar-loteria/primitiva/)
# * [Horóscopo](https://www.lavanguardia.com/horoscopo)
#
# Newsletters
#
# BUSCAR
# [busqueda avanzada](https://stories.lavanguardia.com/search)
#
# SUSCRÍBETE
#
# * Secciones
# * [Al Minuto](https://www.lavanguardia.com/alminuto "Al Minuto")
# * [Internacional](https://www.lavanguardia.com/internacional "Internacional")
# * [Política](https://www.lavanguardia.com/politica "Política")
# * [Opinión](https://www.lavanguardia.com/opinion "Opinión")
# * [Sociedad](https://www.lavanguardia.com/vida "Vida")
# * [Deportes](https://www.lavanguardia.com/deportes "Deportes")
# * [Economía](https://www.lavanguardia.com/economia "Economía")
# * [Ciudades](https://www.lavanguardia.com/local "Local")
# * [Pop](https://www.lavanguardia.com/pop "Pop")
# * [Cultura](https://www.lavanguardia.com/cultura "Cultura")
# * [Sucesos](https://www.lavanguardia.com/sucesos "Sucesos")
# * [Participación](https://www.lavanguardia.com/participacion "Participación")
# * [Suscriptores](https://www.lavanguardia.com/suscriptores "Suscriptores")
# * [Temas](https://www.la
#
# Out: None
# [Step 6: Duration 4.11 seconds| Input tokens: 18,446 | Output tokens: 875]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   lavanguardia_search_url = "https://stories.lavanguardia.com/search?q=apagón+abril+España"
#   lavanguardia_search_page = visit_webpage(lavanguardia_search_url)
#   print(lavanguardia_search_page[:2000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Buscador La Vanguardia
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6398301&cv=2.0&cj=1)
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6398301&cv=2.0&cj=1)
#
# ![](https://www.facebook.com/tr?id=161843274362284&ev=PageView&noscript=1)
#
# [![La
# Vanguardia](https://stories.lavanguardia.com/especial/images/xlogo.png.pagespeed.ic.yov64vP7T4.png)](https://www.la
# vanguardia.com "La Vanguardia")
# [SUSCRÍBETE](https://www.lavanguardia.com/suscripciones/suscribete.html?utm_source=lavanguardia&utm_medium=boton-su
# scripcion&utm_campaign=captacion&utm_content=header)
#
# Buscador
#
# Tipo
# Opinión
# Vídeos
#
# Sección
# Internacional
# Política
# Opinión
# Vida
# Deportes
# Economía
# Local
# Gente
# Cultura
# Sucesos
# La Contra
# Natural
# Tecnología
# Televisión
# Vivo
# Viajes
# Big Vang
# Comer
# Series
# Historia y Vida
# De Moda
# Motor
# Cribeo
# Vanguardia Dossier
# Magazine Lifestyle
#
# Ordenar
# Más reciente primero
# Más antiguo primero
#
# Buscar
# [Borrar](https://stories.lavanguardia.com/search)
#
# Dinero
#
# [Corredor en la junta de Redeia: “Si los generadores hubieran cumplido, no habríamos tenido
# apagón”](https://www.lavanguardia.com/dinero/20250630/10841365/corredor-junta-redeia-operadores-hubieran-cumplido-h
# abriamos-tenido-apagon.html)
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# -----
#
# Iñaki de las Heras
# 30/06/2025 14:41
#
#
#
# Dinero
#
# [El sistema eléctrico necesita una cláusula
# M&M](https://www.lavanguardia.com/dinero/20250704/10855406/apagon-electricidad-redeia-iberdrola-endesa.html)
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------
#
# Iñaki de las Heras
# 04/07/2025 11:00
#
#
#
# Dinero
#
# [Apagón y nucleares](
#
# Out: None
# [Step 7: Duration 4.17 seconds| Input tokens: 23,556 | Output tokens: 996]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 8 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print(lavanguardia_search_page[:4000])  # Print more content to look for explicit reasons cited about the
#   blackout
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Buscador La Vanguardia
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6398301&cv=2.0&cj=1)
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6398301&cv=2.0&cj=1)
#
# ![](https://www.facebook.com/tr?id=161843274362284&ev=PageView&noscript=1)
#
# [![La
# Vanguardia](https://stories.lavanguardia.com/especial/images/xlogo.png.pagespeed.ic.yov64vP7T4.png)](https://www.la
# vanguardia.com "La Vanguardia")
# [SUSCRÍBETE](https://www.lavanguardia.com/suscripciones/suscribete.html?utm_source=lavanguardia&utm_medium=boton-su
# scripcion&utm_campaign=captacion&utm_content=header)
#
# Buscador
#
# Tipo
# Opinión
# Vídeos
#
# Sección
# Internacional
# Política
# Opinión
# Vida
# Deportes
# Economía
# Local
# Gente
# Cultura
# Sucesos
# La Contra
# Natural
# Tecnología
# Televisión
# Vivo
# Viajes
# Big Vang
# Comer
# Series
# Historia y Vida
# De Moda
# Motor
# Cribeo
# Vanguardia Dossier
# Magazine Lifestyle
#
# Ordenar
# Más reciente primero
# Más antiguo primero
#
# Buscar
# [Borrar](https://stories.lavanguardia.com/search)
#
# Dinero
#
# [Corredor en la junta de Redeia: “Si los generadores hubieran cumplido, no habríamos tenido
# apagón”](https://www.lavanguardia.com/dinero/20250630/10841365/corredor-junta-redeia-operadores-hubieran-cumplido-h
# abriamos-tenido-apagon.html)
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# -----
#
# Iñaki de las Heras
# 30/06/2025 14:41
#
#
#
# Dinero
#
# [El sistema eléctrico necesita una cláusula
# M&M](https://www.lavanguardia.com/dinero/20250704/10855406/apagon-electricidad-redeia-iberdrola-endesa.html)
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------
#
# Iñaki de las Heras
# 04/07/2025 11:00
#
#
#
# Dinero
#
# [Apagón y nucleares](https://www.lavanguardia.com/dinero/20250603/10739088/apagon-nucleares.html)
# -------------------------------------------------------------------------------------------------
#
# Jordi Gual
# 03/06/2025 02:00
#
#
#
# Opinión
#
# [Hace falta más luz sobre el
# apagón](https://www.lavanguardia.com/opinion/20250619/10804286/falta-mas-luz-sobre-apagon.html)
# -------------------------------------------------------------------------------------------------------------------
# ---------
#
# Editorial
# 19/06/2025 00:05
#
#
#
# Economía
#
# [Las eléctricas se defienden con un informe que señala a REE como única responsable del
# apagón](https://www.lavanguardia.com/economia/20250623/10817766/electricas-defienden-informe-senala-ree-unica-respo
# nsable-apagon.html)
# -------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------
#
# Pilar Blázquez
# 23/06/2025 13:40
#
#
#
# Opinión
#
# [Las causas del apagón](https://www.lavanguardia.com/opinion/20250527/10727471/causas-apagon.html)
# --------------------------------------------------------------------------------------------------
#
# Creemos que...
# 27/05/2025 23:16
#
#
#
# Economía
#
# [El Gobierno reparte culpas sobre el apagón entre el operador del sistema y las
# eléctricas](https://www.lavanguardia.com/economia/20250617/10797995/informe-sobre-apagon-detecta-hubo-deficiencias-
# control-tension-sistema.html)
# -------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Out: None
# [Step 8: Duration 2.11 seconds| Input tokens: 29,455 | Output tokens: 1,104]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 9 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   reason_apagon = (
#       "El apagón de abril en España fue causado por deficiencias en el control de tensión "
#       "del sistema eléctrico y por el incumplimiento en el funcionamiento de algunos generadores. "
#       "Se repartieron culpas entre el operador del sistema (REE) y las compañías eléctricas, "
#       "según varios informes de fuentes confiables como La Vanguardia."
#   )
#   print(reason_apagon)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# El apagón de abril en España fue causado por deficiencias en el control de tensión del sistema eléctrico y por el
# incumplimiento en el funcionamiento de algunos generadores. Se repartieron culpas entre el operador del sistema
# (REE) y las compañías eléctricas, según varios informes de fuentes confiables como La Vanguardia.
#
# Out: None
# [Step 9: Duration 5.39 seconds| Input tokens: 36,558 | Output tokens: 1,279]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 10 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='Thought:...: None}, annotations=[]), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...ider_specific_fields={}), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(
#       "El apagón del mes de abril en España fue causado por deficiencias en el control de tensión del sistema
#   eléctrico "
#       "y por el incumplimiento en el funcionamiento de algunos generadores. "
#       "Se responsabilizó tanto al operador del sistema (REE) como a las compañías eléctricas, según informes de
#   fuentes confiables."
#   )
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: El apagón del mes de abril en España fue causado por deficiencias en el control de tensión del
# sistema eléctrico y por el incumplimiento en el funcionamiento de algunos generadores. Se responsabilizó tanto al
# operador del sistema (REE) como a las compañías eléctricas, según informes de fuentes confiables.
# [Step 10: Duration 2.57 seconds| Input tokens: 44,052 | Output tokens: 1,414]
# 'El apagón del mes de abril en España fue causado por deficiencias en el control de tensión del sistema eléctrico y por el incumplimiento en el funcionamiento de algunos generadores. Se responsabilizó tanto al operador del sistema (REE) como a las compañías eléctricas, según informes de fuentes confiables.'

# %%
import requests
from smolagents.agents import ToolCallingAgent
from smolagents import tool
from typing import Optional

@tool
def get_most_expensive_pokemon_card(card_name: str) -> str:
    """
    Retrieves the most expensive holofoil version of a Pokémon card by name from the Pokémon TCG API.

    Args:
        card_name (str): The name of the Pokémon card to search for.

    Returns:
        str: A formatted string indicating the name and market price of the most expensive holofoil card
             matching the provided name. If no cards are found, returns a not found message.

    Raises:
        Exception: If the API request fails with a non-200 status code.
    """
    BASE_URL = "https://api.pokemontcg.io/v2/cards"
    params = {"q": f"name:{card_name}"}
    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        cards = response.json().get("data", [])
    else:
        raise Exception(f"API Request failed with status code: {response.status_code}")

    if not cards:
        return "Pokémon card not found"

    most_expensive_card = max(cards, key=lambda card: card.get("tcgplayer", {}).get("prices", {}).get("holofoil", {}).get("market", 0) or 0)
    highest_price = most_expensive_card.get("tcgplayer", {}).get("prices", {}).get("holofoil", {}).get("market", "N/A")

    return f"Most Expensive {card_name} Card: {most_expensive_card['name']} - Market Price: ${highest_price}"


agent = ToolCallingAgent(tools=[get_most_expensive_pokemon_card], model=model)

# %%
agent.run("Cual es el Pikachu más caro?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Cual es el Pikachu más caro?                                                                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gpt-4.1-mini ───────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'get_most_expensive_pokemon_card' with arguments: {'card_name': 'Pikachu'}                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Most Expensive Pikachu Card: Pikachu ★ - Market Price: $2066.66
# [Step 1: Duration 6.15 seconds| Input tokens: 965 | Output tokens: 23]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'El Pikachu más caro es la carta Pikachu ★ con un       │
# │ precio de mercado de $2066.66.'}                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Final answer: El Pikachu más caro es la carta Pikachu ★ con un precio de mercado de $2066.66.
# [Step 2: Duration 1.24 seconds| Input tokens: 2,045 | Output tokens: 59]
# 'El Pikachu más caro es la carta Pikachu ★ con un precio de mercado de $2066.66.'
