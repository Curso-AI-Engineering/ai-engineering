# %% [markdown]
# # LAB7: Prompt Engineering - Expandir

# %% [markdown]
# ## Configuración de la API de OpenAI
# Este código importa las librerías necesarias para trabajar con la API de OpenAI, carga las variables de entorno desde un archivo .env y configura la clave de la API de OpenAI para ser utilizada en las solicitudes a la API.

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.78.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)

# %%
from openai import OpenAI
import getpass

api_key = getpass.getpass("Enter your OpenAI API Key:")

client = OpenAI(api_key = api_key)
# Out:
# Enter your OpenAI API Key:··········

# %% [markdown]
# ## Función para obtener respuestas de GPT
# Este código define una función `get_completion` que toma un prompt y opcionalmente un modelo (por defecto `gpt-3.5-turbo`) y utiliza la API de OpenAI para obtener una respuesta. La función configura la solicitud con una temperatura de 0 para respuestas más deterministas y retorna el contenido de la respuesta.

# %%
def get_completion(prompt, model="gpt-4.1-mini", temperature = 0):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Email respuesta automática

# %%
review = f"""
hoy me ha llegado el reemplazo , de nuevo he de devolverla por el mismo fallo,
pantalla despegandose , tengo otro g9 comprado en pccomponentes de las nuevas REMESAS y todo correcto
modelo: lc49g95tssuxen
s/n: cx8sh4zn700580r
estos numeros son del monitor SIN defectos , cualquier otro numero no sabria si funcionan .
los 2 que he adquirido en amazon son
modelo: lc49g95tssuxen
s/n: cx8sh4zn500822b
estos ultimos numeros de serie vienen con fallos
"""

# %%
prompt = f"""
Eres un asistente de atención al cliente IA.
Tu tarea es enviar una respuesta por correo electrónico a un cliente valorado.
Dado el correo electrónico del cliente delimitado por ```, \
Genera una respuesta para agradecer al cliente su reseña.
Si el sentimiento es positivo o neutral, agradéceles por \
su reseña.
Si el sentimiento es negativo, discúlpate y sugiere que \
pueden ponerse en contacto con el servicio de atención al cliente.
Asegúrate de usar detalles específicos de la reseña.
Escribe en un tono conciso y profesional.
Firma el correo electrónico como `Agente de atención al cliente IA`.
Reseña del cliente: ```{review}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Estimado cliente,
#
# Gracias por tomarse el tiempo de dejarnos su reseña. Lamentamos mucho escuchar que ha experimentado problemas con el reemplazo que recibió. Nos disculpamos por cualquier inconveniente que esto le haya causado.
#
# Apreciamos que haya compartido los detalles específicos de los modelos y números de serie afectados. Su retroalimentación es muy valiosa para nosotros y nos ayudará a mejorar nuestros procesos internos.
#
# Si necesita más asistencia o desea discutir este problema en detalle, no dude en ponerse en contacto con nuestro servicio de atención al cliente. Estamos aquí para ayudarle en todo lo que podamos.
#
# Gracias nuevamente por su reseña y por su continuo apoyo.
#
# Atentamente,
# Agente de atención al cliente IA

# %% [markdown]
# ## Experimenta con la temperatura

# %%
response = get_completion(prompt, temperature = 1)
print(response)
# Out:
# Estimado cliente,
#
# Gracias por tomarse el tiempo de dejarnos su reseña. Lamentamos mucho escuchar sobre los problemas que ha tenido con el monitor que adquirió. Entendemos lo frustrante que debe de ser recibir un reemplazo solo para encontrarse con el mismo fallo.
#
# Si bien nos alegra saber que el otro monitor que compró en PC Componentes ha salido sin problemas, es decepcionante escuchar que los que adquirió en Amazon presentan fallas.
#
# Por favor, acepte nuestras disculpas por las molestias ocasionadas y le sugerimos que se ponga en contacto con nuestro servicio de atención al cliente para encontrar una solución satisfactoria a su situación.
#
# Agradecemos su paciencia y comprensión.
#
# Atentamente,
# Agente de atención al cliente IA

# %%
response = get_completion(prompt, temperature = 0.5)
print(response)
# Out:
# Estimado cliente,
#
# Gracias por compartir su experiencia con nosotros. Lamentamos mucho escuchar que ha tenido problemas con el reemplazo que le enviamos y que presenta el mismo fallo de pantalla despegándose. Entendemos lo frustrante que puede ser esta situación y le pedimos disculpas por las molestias ocasionadas.
#
# Nos alegra saber que el otro monitor que adquirió en PCComponentes de las nuevas REMESAS está en perfectas condiciones y funcionando correctamente. Agradecemos que nos haya proporcionado los detalles específicos de los modelos y números de serie para poder identificar y mejorar nuestros productos.
#
# Si desea, puede ponerse en contacto con nuestro servicio de atención al cliente para que podamos resolver este problema de la mejor manera posible. Estamos aquí para ayudarle en todo lo que necesite.
#
# Gracias nuevamente por su reseña y por compartir su experiencia con nosotros.
#
# Atentamente,
# Agente de atención al cliente IA
