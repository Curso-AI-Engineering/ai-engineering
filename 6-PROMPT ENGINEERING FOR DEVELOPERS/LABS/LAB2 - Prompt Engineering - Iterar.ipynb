# %% [markdown]
# # LAB2 - Prompt Engineering - Iterar

# %% [markdown]
# ## Configuración de la API de OpenAI
# Este código importa las librerías necesarias para trabajar con la API de OpenAI y configura la clave de la API de OpenAI para ser utilizada en las solicitudes a la API.

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.86.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
from openai import OpenAI
import getpass

api_key = getpass.getpass("Enter your OpenAI API Key:")

client = OpenAI(api_key = api_key)
# Out:
# Enter your OpenAI API Key:··········

# %% [markdown]
# ## Función para obtener respuestas de GPT
# Este código define una función `get_completion` que toma un prompt y opcionalmente un modelo (por defecto gpt-3.5-turbo) y utiliza la API de OpenAI para obtener una respuesta. La función configura la petición con una temperatura de 0 para respuestas más deterministas y retorna el contenido de la respuesta.

# %%
def get_completion(prompt, model="gpt-4.1-mini", temperature = 0):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Generar la descripción de un producto a partir de sus datos técnicos

# %%
product_description = """

Características principales

Ligereza
Cuadro ligero de aluminio 6061 Serie Hydro.


Precisión
Transmisión monoplato SRAM NX Eagle


Amortiguación
Rockshox Judy Silver TK R 29er 100mm TA15/110 // Matte Black

Información técnica
Cuadro
Fabricado en aluminio de alta calidad, ligero y rígido.
Geometría de carrera mejorada para mayor estabilidad y capacidad de respuesta.

Grupo
Transmisión SRAM NX Eagle de 12 velocidades para cambios de marcha precisos
Biela NX Eagle 175 mm // 32T
Casete SRAM PG-1230 Eagle // 12s // 11-50T
Desviador SRAM NX Eagle // 12s

Ruedas
Ruedas Forza XCD-SL 29", diseñadas para un gran rendimiento en la montaña.
Rueda delantera Forza XCD-SL, 29er // TA 15x110mm // Clincher-TLR // 23mm
Rueda trasera Forza XCD SL // TA12-148 // 23c // TLR

Neumáticos
Vittoria Barzo // 622x55 // Full Black

Frenos
Frenos de disco SRAM Level T DB para una frenada fiable.

Horquilla
Horquilla Rockshox Judy Silver TK R de 100 mm para una conducción suave en terrenos difíciles.

Manillar
4ZA Stratos Flatbar // 740mm

Potencia
Forza Stratos // 90 mm // Black Glossy

Garantía (años)
3

"""

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Technical specifications: ```{product_description}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Descubre la bicicleta perfecta para los amantes del mountain bike que buscan ligereza, precisión y rendimiento en cada ruta. Este modelo cuenta con un cuadro de aluminio 6061 Serie Hydro, que combina alta calidad, ligereza y rigidez para ofrecer una geometría de carrera mejorada, garantizando mayor estabilidad y capacidad de respuesta en todo tipo de terrenos.
#
# Equipada con la transmisión monoplato SRAM NX Eagle de 12 velocidades, disfrutarás de cambios de marcha precisos y suaves gracias a su biela de 175 mm y casete 11-50T. Las ruedas Forza XCD-SL de 29" están diseñadas para maximizar el rendimiento en montaña, con neumáticos Vittoria Barzo 622x55 que aseguran un agarre óptimo y durabilidad.
#
# La horquilla Rockshox Judy Silver TK R de 100 mm proporciona una amortiguación eficaz para una conducción cómoda y controlada en terrenos difíciles, mientras que los frenos de disco SRAM Level T DB garantizan una frenada fiable y segura en cualquier situación.
#
# Complementan el conjunto el manillar 4ZA Stratos Flatbar de 740 mm y la potencia Forza Stratos de 90 mm en acabado Black Glossy, que aportan control y ergonomía para una experiencia de manejo superior.
#
# Además, esta bicicleta cuenta con una garantía de 3 años, respaldando su calidad y durabilidad. Prepárate para conquistar cualquier sendero con esta máquina diseñada para ofrecerte el mejor rendimiento y confort.

# %% [markdown]
# ## Primera iteración: El texto es demasiado largo

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Use at most 50 words.

Technical specifications: ```{product_description}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Bicicleta de montaña ligera con cuadro de aluminio 6061, transmisión SRAM NX Eagle de 12 velocidades y suspensión Rockshox Judy Silver TK de 100 mm. Ruedas Forza XCD-SL 29" y frenos de disco SRAM Level T para un rendimiento y control excepcionales en cualquier terreno.

# %% [markdown]
# ## Segunda iteración; ¡El texto es demasiado general, la audiencia es Instagram!

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended fan Instagram Post.
Use Emojis.
We need the text in English
Use at most 50 words.

Technical specifications: ```{product_description}```
"""
response = get_completion(prompt)
print(response)
# Out:
# 🚵‍♂️ Ride light, ride precise! Aluminum 6061 frame, SRAM NX Eagle 12-speed, Rockshox Judy Silver 100mm fork, and Vittoria Barzo tires for smooth, powerful mountain adventures. Ready to conquer every trail! 🌄✨ #MountainBike #RideWithPrecision #AdventureAwaits

# %% [markdown]
# ## Tercera iteración; Crea un JSON de resultado

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended fan Instagram Post.
Use Emojis.
We need the text in Euskera
Use at most 50 words.

The respose MUST be a JSON with this format:
- name: Product name
- description: Instagram description in language Euskera
- category: Product category. The possible categories are: sports, swimming, mountain, cycling, sex position, rubgy, combat
- details: An array with product details
- slug: Create a SEO optimized slug using the product name

Technical specifications: ```{product_description}```
"""
response = get_completion(prompt)
print(response)

#
# Out:
# ```json
# {
#   "name": "Forza Stratos 29er",
#   "description": "🚵‍♂️ Arina eta zehatza! Forza Stratos 29er aluminiozko marko sendoarekin, SRAM NX Eagle transmisioarekin eta Rockshox amortiguazioarekin. Mendi abenturak prest! 🌄✨ #MendikoBizikleta #ForzaStratos",
#   "category": "mountain",
#   "details": [
#     "Aluminio 6061 Serie Hydro markoa",
#     "SRAM NX Eagle 12 abiadura transmisioa",
#     "Rockshox Judy Silver TK R 29er 100mm amortiguazioa",
#     "Forza XCD-SL 29\" gurpilak",
#     "Vittoria Barzo 622x55 neumatikoak",
#     "SRAM Level T DB disko frenak",
#     "3 urteko bermea"
#   ],
#   "slug": "forza-stratos-29er"
# }
# ```
